# %% [markdown]
# # Word Embedding using tensorflow keras

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import csv
import nltk
import io

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.model_selection import train_test_split

from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

from gensim.models import Word2Vec
from gensim.models import KeyedVectors

from nltk.cluster import KMeansClusterer
from nltk.tokenize import word_tokenize

from sklearn import cluster
from sklearn import metrics

from tensorflow.keras.preprocessing.text import one_hot
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ## Création d'un réseau de neurones à partir de vecteurs de mots

# %%
vocab_size = 1000
embedding_dim = 16
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_portion = .8

# %% [markdown]
# ### Récupérer nos données

# %%
data = pd.read_csv("my_csv_clean.csv",sep = ',') #we got that csv after running the Text Preprocessing file
data.columns = ['tweet', 'class']
    
X = data['tweet']
y = data['class'] 

categories = ["NotSexist", "Sexist"]

X_train, X_test, y_train , y_test = train_test_split(X , y ,test_size=0.3)

X = list(X)
y = [categories[i] for i in y]
X_train = list(X_train)
X_test = list(X_test)
y_train = [categories[i] for i in y_train]
y_test = [categories[i] for i in y_test]
print(y_train)
# Out:
# ['Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'Sexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', ...

# %% [markdown]
# ### Tokeniser les phrases

# %%
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(X_train)

# %%
word_index = tokenizer.word_index
total_words = len(word_index)+1 # le +1 est pour le OOV
print("Total_words = ", total_words)
print("Word index : \n", word_index)
# Out:
# Total_words =  9660
# Word index :
#  {'<OOV>': 1, 'de': 2, 'pour': 3, 'balancetonporc': 4, 'du': 5, 'pas': 6, 'qui': 7, 'femme': 8, 'sur': 9, 'dans': 10, 'est': 11, 'sexisme': 12, 'on': 13, 'ce': 14, 'avec': 15, 'moiaussi': 16, 'ne': 17, 'il': 18, 'femmes': 19, 'par': 20, 'plus': 21, 'ca': 22, 'vous': 23, 'mais': 24, 'ou': 25, 'contre': 26, 'metoo': 27, 'fait': 28, 'comme': 29, 'merkel': 30, 'sexiste': 31, 'via': 32, 'angela': 33, 'si': 34, 'elle': 35, 'tout': 36, 'sont': 37, 'faire': 38, 'cette': 39, 'nous': 40, 'aux': 41, 'etre': 42, 'bien': 43, 'apres': 44, 'aussi': 45, 'y': 46, 'quand': 47, 'ont': 48, 'ensemblecontrelesexisme': 49, 'monde': 50, 'viol': 51, 'homme': 52, 'me': 53, 'leur': 54, 'jai': 55, 'harcelement': 56, 'meme': 57, 'ironie': 58, 'mouvement': 59, 'bleues': 60, 'france': 61, 'suis': 62, 'hommes': 63, 'enceinte': 64, 'une': 65, 'journee': 66, 'etmaintenant': 67, 'nest': 68, 'rien': 69, 'merci': 70, 'macron': 71, 'alors': 72, 'royal': 73, 'ete': 74, 'salope': 75, 'non': 76, 'dit': 77, 'segolene': 78, 'moi': 79, 'travail': 80, 'match': 81, 'egalite': 82, 'encore': 83, 'aujourhui': 84, 'fille': 85, 'tres': 86, 'avoir': 87, 'quon': 88, 'marleneschiappa': 89, 'peut': 90, 'va': 91, 'ans': 92, 'quil': 93, 'politique': 94, 'pourquoi': 95, 'feministe': 96, 'tous': 97, 'may': 98, 'toujours': 99, 'theresa': 100, 'autres': 101, 'entre': 102, 'sans': 103, 'notre': 104, 'un': 105, '1': 106, 'faut': 107, 'dire': 108, 'lui': 109, 'quelle': 110, 'payetashnek': 111, 'deneuve': 112, 'na': 113, 'ces': 114, 'taubira': 115, 'christiane': 116, 'donc': 117, 'parce': 118, 'nos': 119, 'parole': 120, 'feminisme': 121, 'bon': 122, 'parle': 123, 'catherine': 124, 'votre': 125, 'c': 126, '2018': 127, 'comment': 128, 'juste': 129, 'tir': 130, 'peu': 131, 'voir': 132, 'oui': 133, 'collectif': 134, 'la': 135, 'violences': 136, 'darmanin': 137, 'victimes': 138, 'a': 139, 'as': 140, 'toutes': 141, 'autre': 142, 'affaire': 143, 'avant': 144, 'deux': 145, 'beaucoup': 146, 'sport': 147, 'fois': 148, 'ils': 149, 'bravo': 150, 'annee': 151, 'parler': 152, 'elles': 153, 'trop': 154, 'cela': 155, '2017': 156, 'racisme': 157, 'amp': 158, 'quoi': 159, 'depuis': 160, 'ministre': 161, 'allemagne': 162, '2': 163, 'sexuel': 164, 'veut': 165, 'doit': 166, 'en': 167, 'moins': 168, 'diffamation': 169, 'avait': 170, 'face': 171, 'le': 172, 'auroreberge': 173, 'justice': 174, 'place': 175, 'temps': 176, 'janvier': 177, 'demande': 178, 'te': 179, 'aurait': 180, 'bonne': 181, 'lance': 182, '25': 183, 'soir': 184, 'droit': 185, 'premiere': 186, 'vrai': 187, 'balance': 188, 'propos': 189, 'accuse': 190, 'jour': 191, 'video': 192, 'sous': 193, 'pense': 194, 'pute': 195, 'marche': 196, 'je': 197, 'emmanuel': 198, 'gens': 199, 'vie': 200, 'soit': 201, 'coup': 202, 'jamais': 203, 'mois': 204, 'selon': 205, 'nationale': 206, 'parti': 207, 'quun': 208, 'genre': 209, 'egalitefh': 210, 'mettre': 211, 'sera': 212, 'demain': 213, 'sexuelles': 214, 'sexuelle': 215, 'campagne': 216, 'porc': 217, 'car': 218, 'vient': 219, 'reste': 220, 'nouvelle': 221, 'leurs': 222, 'tellement': 223, 'vos': 224, 'soutien': 225, 'maintenant': 226, 'accord': 227, 'chez': 228, 'grosse': 229, 'time': 230, 'francais': 231, 'mal': 232, 'personne': 233, 'silence': 234, 'quune': 235, 'mieux': 236, 'sandra': 237, 'premier': 238, 'passe': 239, 'puissante': 240, 'grand': 241, 'd': 242, 'trump': 243, 'discours': 244, 'certains': 245, 'emmanuelmacron': 246, 'mere': 247, 'victime': 248, 'weinstein': 249, 'ni': 250, 'europe': 251, 'denonce': 252, 'paris': 253, 'societe': 254, 'fillon': 255, 'millions': 256, 'muller': 257, 'font': 258, 'ny': 259, 'toi': 260, 'vraiment': 261, 'vu': 262, 'twitter': 263, 'droite': 264, 'probleme': 265, 'sexistes': 266, 'nom': 267, 'les': 268, 'es': 269, 'belle': 270, 'journaliste': 271, 'dis': 272, 'medias': 273, 'deja': 274, 'etait': 275, 'filles': 276, 'courage': 277, 'avenir': 278, 'aurore': 279, 'berge': 280, 'allez': 281, 'chanceliere': 282, 'mec': 283, 'ceux': 284, 'quelques': 285, 'gros': 286, 'article': 287 ...

# %%
train_sequences = tokenizer.texts_to_sequences(X_train)
train_filled = pad_sequences(train_sequences, padding=padding_type, maxlen=max_length)

validation_sequences = tokenizer.texts_to_sequences(X_test)
validation_filled = pad_sequences(validation_sequences, padding=padding_type, maxlen=max_length)

# %% [markdown]
# ### Tokeniser les catégories

# %%
label_tokenizer = Tokenizer()
label_tokenizer.fit_on_texts(y)

training_label_seq = np.array(label_tokenizer.texts_to_sequences(y_train))
validation_label_seq = np.array(label_tokenizer.texts_to_sequences(y_test))

# %% [markdown]
# ### Création du modèle

# %%
modele = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])
modele.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
modele.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_16 (Embedding)    (None, 120, 16)           16000
#
#  global_average_pooling1d_16  (None, 16)               0
#   (GlobalAveragePooling1D)
#
#  dense_32 (Dense)            (None, 24)                408
#
#  dense_33 (Dense)            (None, 6)                 150
#
# =================================================================
# Total params: 16,558
# Trainable params: 16,558
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 30
history = modele.fit(train_filled, training_label_seq, epochs=num_epochs, 
                    validation_data=(validation_filled, validation_label_seq), 
                    verbose=2)
# Out:
# Epoch 1/30
# 69/69 - 1s - loss: 1.6086 - accuracy: 0.6704 - val_loss: 1.3402 - val_accuracy: 0.6857 - 585ms/epoch - 8ms/step
# Epoch 2/30
# 69/69 - 0s - loss: 0.9900 - accuracy: 0.6859 - val_loss: 0.7330 - val_accuracy: 0.6857 - 113ms/epoch - 2ms/step
# Epoch 3/30
# 69/69 - 0s - loss: 0.6760 - accuracy: 0.6859 - val_loss: 0.6470 - val_accuracy: 0.6857 - 116ms/epoch - 2ms/step
# Epoch 4/30
# 69/69 - 0s - loss: 0.6383 - accuracy: 0.6859 - val_loss: 0.6325 - val_accuracy: 0.6857 - 124ms/epoch - 2ms/step
# Epoch 5/30
# 69/69 - 0s - loss: 0.6283 - accuracy: 0.6859 - val_loss: 0.6272 - val_accuracy: 0.6857 - 122ms/epoch - 2ms/step
# Epoch 6/30
# 69/69 - 0s - loss: 0.6245 - accuracy: 0.6859 - val_loss: 0.6229 - val_accuracy: 0.6857 - 130ms/epoch - 2ms/step
# Epoch 7/30
# 69/69 - 0s - loss: 0.6226 - accuracy: 0.6859 - val_loss: 0.6208 - val_accuracy: 0.6857 - 131ms/epoch - 2ms/step
# Epoch 8/30
# 69/69 - 0s - loss: 0.6202 - accuracy: 0.6859 - val_loss: 0.6193 - val_accuracy: 0.6857 - 168ms/epoch - 2ms/step
# Epoch 9/30
# 69/69 - 0s - loss: 0.6181 - accuracy: 0.6859 - val_loss: 0.6179 - val_accuracy: 0.6857 - 154ms/epoch - 2ms/step
# Epoch 10/30
# 69/69 - 0s - loss: 0.6169 - accuracy: 0.6859 - val_loss: 0.6169 - val_accuracy: 0.6857 - 122ms/epoch - 2ms/step
# Epoch 11/30
# 69/69 - 0s - loss: 0.6142 - accuracy: 0.6859 - val_loss: 0.6155 - val_accuracy: 0.6857 - 125ms/epoch - 2ms/step
# Epoch 12/30
# 69/69 - 0s - loss: 0.6129 - accuracy: 0.6859 - val_loss: 0.6124 - val_accuracy: 0.6857 - 126ms/epoch - 2ms/step
# Epoch 13/30
# 69/69 - 0s - loss: 0.6092 - accuracy: 0.6859 - val_loss: 0.6101 - val_accuracy: 0.6857 - 125ms/epoch - 2ms/step
# Epoch 14/30
# 69/69 - 0s - loss: 0.6062 - accuracy: 0.6859 - val_loss: 0.6085 - val_accuracy: 0.6857 - 124ms/epoch - 2ms/step
# Epoch 15/30
# 69/69 - 0s - loss: 0.6020 - accuracy: 0.6859 - val_loss: 0.6037 - val_accuracy: 0.6857 - 129ms/epoch - 2ms/step
# Epoch 16/30
# 69/69 - 0s - loss: 0.5975 - accuracy: 0.6859 - val_loss: 0.6000 - val_accuracy: 0.6857 - 135ms/epoch - 2ms/step
# Epoch 17/30
# 69/69 - 0s - loss: 0.5913 - accuracy: 0.6859 - val_loss: 0.5951 - val_accuracy: 0.6857 - 153ms/epoch - 2ms/step
# Epoch 18/30
# 69/69 - 0s - loss: 0.5846 - accuracy: 0.6859 - val_loss: 0.5889 - val_accuracy: 0.6857 - 167ms/epoch - 2ms/step
# Epoch 19/30
# 69/69 - 0s - loss: 0.5761 - accuracy: 0.6863 - val_loss: 0.5814 - val_accuracy: 0.6857 - 139ms/epoch - 2ms/step
# Epoch 20/30
# 69/69 - 0s - loss: 0.5663 - accuracy: 0.6882 - val_loss: 0.5735 - val_accuracy: 0.6868 - 177ms/epoch - 3ms/step
# Epoch 21/30
# 69/69 - 0s - loss: 0.5552 - accuracy: 0.6918 - val_loss: 0.5648 - val_accuracy: 0.6931 - 197ms/epoch - 3ms/step
# Epoch 22/30
# 69/69 - 0s - loss: 0.5448 - accuracy: 0.7059 - val_loss: 0.5585 - val_accuracy: 0.6910 - 148ms/epoch - 2ms/step
# Epoch 23/30
# 69/69 - 0s - loss: 0.5305 - accuracy: 0.7099 - val_loss: 0.5461 - val_accuracy: 0.6963 - 192ms/epoch - 3ms/step
# Epoch 24/30
# 69/69 - 0s - loss: 0.5158 - accuracy: 0.7236 - val_loss: 0.5373 - val_accuracy: 0.7132 - 199ms/epoch - 3ms/step
# Epoch 25/30
# 69/69 - 0s - loss: 0.5017 - accuracy: 0.7354 - val_loss: 0.5287 - val_accuracy: 0.7259 - 174ms/epoch - 3ms/step
# Epoch 26/30
# 69/69 - 0s - loss: 0.4883 - accuracy: 0.7499 - val_loss: 0.5192 - val_accuracy: 0.7270 - 157ms/epoch - 2ms/step
# Epoch 27/30
# 69/69 - 0s - loss: 0.4737 - accuracy: 0.7644 - val_loss: 0.5102 - val_accuracy: 0.7323 - 152ms/epoch - 2ms/step
# Epoch 28/30
# 69/69 - 0s - loss: 0.4609 - accuracy: 0.7739 - val_loss: 0.5024 - val_accuracy: 0.7386 - 180ms/epoch - 3ms/step
# Epoch 29/30
# 69/69 - 0s - loss: 0.4475 - accuracy: 0.7830 - val_loss: 0.4968 - val_accuracy: 0.7481 - 196ms/epoch - 3ms/step
# Epoch 30/30
# 69/69 - 0s - loss: 0.4352 - accuracy: 0.7857 - val_loss: 0.4909 - val_accuracy: 0.7492 - 132ms/epoch - 2ms/step

# %% [markdown]
# ### Représentation graphique des différentes accuracy obtenues

# %%
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
y_pred = modele.predict(validation_filled)
predictions = np.argmax(y_pred,axis=1)

for i in range(len(predictions)):
    predictions[i] = predictions[i] - 1
    
true_labels = []
for i in y_test:
    if(i=='NotSexist'):
        true_labels.append(0)
    else:
        true_labels.append(1)
    
print("Accuracy : ", np.mean(predictions == true_labels))
metrics.confusion_matrix(true_labels, predictions)
# Out:
# Accuracy :  0.7492063492063492
# array([[584,  64],
#        [173, 124]])

# %% [markdown]
# ### Pour la visualisation de nos vecteurs de mots sur https://projector.tensorflow.org/

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
def decode_sentence(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

# %%
e = modele.layers[0]
weights = e.get_weights()[0]
print(weights.shape)
# Out:
# (1000, 16)

# %%
out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('meta.tsv', 'w', encoding='utf-8')
for word_num in range(1, vocab_size):
    word = reverse_word_index[word_num]
    embeddings = weights[word_num]
    out_m.write(word + "\n")
    out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")
out_v.close()
out_m.close()

# %%
#On a essayé d'ajouter des poids à certains mots, malheureusement sans succès
'''import re
stereotype_liste = []

with open('stereotype_liste.txt',encoding='utf8') as f:
    stereotype_liste = f.readlines()

weighted_words = [re.sub(r"\n",'',i) for i in stereotype_liste]

print(weighted_words)

from sklearn.feature_extraction.text import TfidfVectorizer
   
data = pd.read_csv("my_csv_clean.csv",sep = ',') #we got that csv after running the Text Preprocessing file
data.columns = ['tweet', 'class'] 

X = data['tweet']
y = data['class'] 

categories = ["NotSexist", "Sexist"]

vectorizer = TfidfVectorizer()
new_X = vectorizer.fit_transform(X)
vectorizer.get_feature_names_out()'''
# Out:
# 'import re\nstereotype_liste = []\n\nwith open(\'stereotype_liste.txt\',encoding=\'utf8\') as f:\n    stereotype_liste = f.readlines()\n\nweighted_words = [re.sub(r"\n",\'\',i) for i in stereotype_liste]\n\nprint(weighted_words)\n\nfrom sklearn.feature_extraction.text import TfidfVectorizer\n   \ndata = pd.read_csv("my_csv_clean.csv",sep = \',\') #we got that csv after running the Text Preprocessing file\ndata.columns = [\'tweet\', \'class\'] \n\nX = data[\'tweet\']\ny = data[\'class\'] \n\ncategories = ["NotSexist", "Sexist"]\n\nvectorizer = TfidfVectorizer()\nnew_X = vectorizer.fit_transform(X)\nvectorizer.get_feature_names_out()'

# %% [markdown]
# ## Création d'un réseau de neurone à partir de vecteur de mots avec recours à de l'oversampling

# %%
data = pd.read_csv("my_csv_clean.csv",sep = ',') #we got that csv after running the Text Preprocessing file
data.columns = ['tweet', 'class']

X = data['tweet']
y = data['class'] 

X_train, X_test, y_train , y_test = train_test_split(X , y ,test_size=0.3)

X = list(X)
y = [categories[i] for i in y]
X_test = list(X_test)
y_train = [categories[i] for i in y_train]
y_test = [categories[i] for i in y_test]

ros = RandomOverSampler()
X_ros_train, y_ros_train = ros.fit_resample(np.array(X_train).reshape(-1,1), y_train)# new class distribution 
X_ros_test, y_ros_test = ros.fit_resample(np.array(X_test).reshape(-1,1), y_test)# new class distribution 
X_ros_train = X_ros_train.tolist()
X_ros_test = X_ros_test.tolist()

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(X_ros_train)

word_index = tokenizer.word_index
total_words = len(word_index)+1 #1 for oov word

train_sequences = tokenizer.texts_to_sequences(X_ros_train)
train_filled = pad_sequences(train_sequences, padding=padding_type, maxlen=max_length)

validation_sequences = tokenizer.texts_to_sequences(X_ros_test)
validation_filled = pad_sequences(validation_sequences, padding=padding_type, maxlen=max_length)

label_tokenizer = Tokenizer()
label_tokenizer.fit_on_texts(y)

training_label_seq = np.array(label_tokenizer.texts_to_sequences(y_ros_train))
validation_label_seq = np.array(label_tokenizer.texts_to_sequences(y_ros_test))

modele = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])
modele.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
modele.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_17 (Embedding)    (None, 120, 16)           16000
#
#  global_average_pooling1d_17  (None, 16)               0
#   (GlobalAveragePooling1D)
#
#  dense_34 (Dense)            (None, 24)                408
#
#  dense_35 (Dense)            (None, 6)                 150
#
# =================================================================
# Total params: 16,558
# Trainable params: 16,558
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 30
history = modele.fit(train_filled, training_label_seq, epochs=num_epochs, 
                    validation_data=(validation_filled, validation_label_seq), 
                    verbose=2)
# Out:
# Epoch 1/30
# 95/95 - 1s - loss: 1.5575 - accuracy: 0.4798 - val_loss: 1.1594 - val_accuracy: 0.5000 - 528ms/epoch - 6ms/step
# Epoch 2/30
# 95/95 - 0s - loss: 0.8538 - accuracy: 0.4901 - val_loss: 0.7255 - val_accuracy: 0.5000 - 144ms/epoch - 2ms/step
# Epoch 3/30
# 95/95 - 0s - loss: 0.7115 - accuracy: 0.5083 - val_loss: 0.7030 - val_accuracy: 0.5000 - 152ms/epoch - 2ms/step
# Epoch 4/30
# 95/95 - 0s - loss: 0.7007 - accuracy: 0.4990 - val_loss: 0.6986 - val_accuracy: 0.5000 - 156ms/epoch - 2ms/step
# Epoch 5/30
# 95/95 - 0s - loss: 0.6967 - accuracy: 0.5096 - val_loss: 0.6964 - val_accuracy: 0.5000 - 159ms/epoch - 2ms/step
# Epoch 6/30
# 95/95 - 0s - loss: 0.6959 - accuracy: 0.4964 - val_loss: 0.6953 - val_accuracy: 0.5000 - 154ms/epoch - 2ms/step
# Epoch 7/30
# 95/95 - 0s - loss: 0.6956 - accuracy: 0.5017 - val_loss: 0.6956 - val_accuracy: 0.5000 - 156ms/epoch - 2ms/step
# Epoch 8/30
# 95/95 - 0s - loss: 0.6938 - accuracy: 0.5238 - val_loss: 0.6950 - val_accuracy: 0.5000 - 154ms/epoch - 2ms/step
# Epoch 9/30
# 95/95 - 0s - loss: 0.6936 - accuracy: 0.5083 - val_loss: 0.6944 - val_accuracy: 0.5000 - 181ms/epoch - 2ms/step
# Epoch 10/30
# 95/95 - 0s - loss: 0.6919 - accuracy: 0.5195 - val_loss: 0.6939 - val_accuracy: 0.5085 - 241ms/epoch - 3ms/step
# Epoch 11/30
# 95/95 - 0s - loss: 0.6914 - accuracy: 0.5361 - val_loss: 0.6965 - val_accuracy: 0.5000 - 181ms/epoch - 2ms/step
# Epoch 12/30
# 95/95 - 0s - loss: 0.6923 - accuracy: 0.5414 - val_loss: 0.6938 - val_accuracy: 0.5000 - 178ms/epoch - 2ms/step
# Epoch 13/30
# 95/95 - 0s - loss: 0.6895 - accuracy: 0.5397 - val_loss: 0.6941 - val_accuracy: 0.5000 - 189ms/epoch - 2ms/step
# Epoch 14/30
# 95/95 - 0s - loss: 0.6887 - accuracy: 0.6258 - val_loss: 0.6935 - val_accuracy: 0.4969 - 164ms/epoch - 2ms/step
# Epoch 15/30
# 95/95 - 0s - loss: 0.6878 - accuracy: 0.5344 - val_loss: 0.6978 - val_accuracy: 0.5000 - 184ms/epoch - 2ms/step
# Epoch 16/30
# 95/95 - 0s - loss: 0.6863 - accuracy: 0.5970 - val_loss: 0.6935 - val_accuracy: 0.4969 - 205ms/epoch - 2ms/step
# Epoch 17/30
# 95/95 - 0s - loss: 0.6841 - accuracy: 0.6692 - val_loss: 0.6934 - val_accuracy: 0.5000 - 173ms/epoch - 2ms/step
# Epoch 18/30
# 95/95 - 0s - loss: 0.6821 - accuracy: 0.6192 - val_loss: 0.6957 - val_accuracy: 0.5000 - 181ms/epoch - 2ms/step
# Epoch 19/30
# 95/95 - 0s - loss: 0.6801 - accuracy: 0.6109 - val_loss: 0.6942 - val_accuracy: 0.5000 - 175ms/epoch - 2ms/step
# Epoch 20/30
# 95/95 - 0s - loss: 0.6775 - accuracy: 0.6106 - val_loss: 0.6954 - val_accuracy: 0.5069 - 165ms/epoch - 2ms/step
# Epoch 21/30
# 95/95 - 0s - loss: 0.6724 - accuracy: 0.7116 - val_loss: 0.6998 - val_accuracy: 0.5000 - 169ms/epoch - 2ms/step
# Epoch 22/30
# 95/95 - 0s - loss: 0.6708 - accuracy: 0.6248 - val_loss: 0.6933 - val_accuracy: 0.4969 - 230ms/epoch - 2ms/step
# Epoch 23/30
# 95/95 - 0s - loss: 0.6630 - accuracy: 0.7179 - val_loss: 0.6946 - val_accuracy: 0.5000 - 190ms/epoch - 2ms/step
# Epoch 24/30
# 95/95 - 0s - loss: 0.6558 - accuracy: 0.6566 - val_loss: 0.6944 - val_accuracy: 0.5000 - 257ms/epoch - 3ms/step
# Epoch 25/30
# 95/95 - 0s - loss: 0.6499 - accuracy: 0.7589 - val_loss: 0.7003 - val_accuracy: 0.5031 - 194ms/epoch - 2ms/step
# Epoch 26/30
# 95/95 - 0s - loss: 0.6410 - accuracy: 0.7997 - val_loss: 0.7081 - val_accuracy: 0.5085 - 165ms/epoch - 2ms/step
# Epoch 27/30
# 95/95 - 0s - loss: 0.6309 - accuracy: 0.7944 - val_loss: 0.7067 - val_accuracy: 0.5023 - 157ms/epoch - 2ms/step
# Epoch 28/30
# 95/95 - 0s - loss: 0.6175 - accuracy: 0.7937 - val_loss: 0.7295 - val_accuracy: 0.5085 - 171ms/epoch - 2ms/step
# Epoch 29/30
# 95/95 - 0s - loss: 0.6048 - accuracy: 0.8371 - val_loss: 0.7002 - val_accuracy: 0.4969 - 257ms/epoch - 3ms/step
# Epoch 30/30
# 95/95 - 0s - loss: 0.5858 - accuracy: 0.8099 - val_loss: 0.7142 - val_accuracy: 0.4969 - 178ms/epoch - 2ms/step

# %%
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
y_pred = modele.predict(validation_filled)
predictions = np.argmax(y_pred,axis=1)

for i in range(len(predictions)):
    predictions[i] = predictions[i] - 1
    
true_labels = []
for i in y_ros_test:
    if(i=='NotSexist'):
        true_labels.append(0)
    else:
        true_labels.append(1)
print("Accuracy : ", np.mean(predictions == true_labels))
metrics.confusion_matrix(true_labels, predictions)
# Out:
# Accuracy :  0.49691833590138673
# array([[632,  17],
#        [636,  13]])

# %% [markdown]
# ## Création d'un réseau de neurone à partir de vecteur de mots avec recours à de l'undersampling

# %%
data = pd.read_csv("my_csv_clean.csv",sep = ',') #we got that csv after running the Text Preprocessing file
data.columns = ['tweet', 'class']

X = data['tweet']
y = data['class'] 

X_train, X_test, y_train , y_test = train_test_split(X , y ,test_size=0.3)

X = list(X)
y = [categories[i] for i in y]
X_test = list(X_test)
y_train = [categories[i] for i in y_train]
y_test = [categories[i] for i in y_test]

rus = RandomUnderSampler()
X_rus_train, y_rus_train = rus.fit_resample(np.array(X_train).reshape(-1,1), y_train)# new class distribution 
X_rus_test, y_rus_test = rus.fit_resample(np.array(X_test).reshape(-1,1), y_test)# new class distribution 
X_rus_train = X_rus_train.tolist()
X_rus_test = X_rus_test.tolist()

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(X_rus_train)

word_index = tokenizer.word_index
total_words = len(word_index)+1

train_sequences = tokenizer.texts_to_sequences(X_rus_train)
train_filled = pad_sequences(train_sequences, padding=padding_type, maxlen=max_length)

validation_sequences = tokenizer.texts_to_sequences(X_rus_test)
validation_filled = pad_sequences(validation_sequences, padding=padding_type, maxlen=max_length)

label_tokenizer = Tokenizer()
label_tokenizer.fit_on_texts(y)

training_label_seq = np.array(label_tokenizer.texts_to_sequences(y_rus_train))
validation_label_seq = np.array(label_tokenizer.texts_to_sequences(y_rus_test))

modele = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])
modele.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
modele.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_18 (Embedding)    (None, 120, 16)           16000
#
#  global_average_pooling1d_18  (None, 16)               0
#   (GlobalAveragePooling1D)
#
#  dense_36 (Dense)            (None, 24)                408
#
#  dense_37 (Dense)            (None, 6)                 150
#
# =================================================================
# Total params: 16,558
# Trainable params: 16,558
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 30
history = modele.fit(train_filled, training_label_seq, epochs=num_epochs, 
                    validation_data=(validation_filled, validation_label_seq), 
                    verbose=2)
# Out:
# Epoch 1/30
# 44/44 - 0s - loss: 1.6926 - accuracy: 0.4708 - val_loss: 1.5653 - val_accuracy: 0.5000 - 500ms/epoch - 11ms/step
# Epoch 2/30
# 44/44 - 0s - loss: 1.3647 - accuracy: 0.5000 - val_loss: 1.1155 - val_accuracy: 0.5000 - 86ms/epoch - 2ms/step
# Epoch 3/30
# 44/44 - 0s - loss: 0.9250 - accuracy: 0.5000 - val_loss: 0.7889 - val_accuracy: 0.5000 - 126ms/epoch - 3ms/step
# Epoch 4/30
# 44/44 - 0s - loss: 0.7466 - accuracy: 0.5078 - val_loss: 0.7219 - val_accuracy: 0.5000 - 136ms/epoch - 3ms/step
# Epoch 5/30
# 44/44 - 0s - loss: 0.7138 - accuracy: 0.5085 - val_loss: 0.7075 - val_accuracy: 0.5000 - 95ms/epoch - 2ms/step
# Epoch 6/30
# 44/44 - 0s - loss: 0.7047 - accuracy: 0.4993 - val_loss: 0.7021 - val_accuracy: 0.5000 - 85ms/epoch - 2ms/step
# Epoch 7/30
# 44/44 - 0s - loss: 0.7006 - accuracy: 0.5028 - val_loss: 0.6994 - val_accuracy: 0.5000 - 100ms/epoch - 2ms/step
# Epoch 8/30
# 44/44 - 0s - loss: 0.6979 - accuracy: 0.5036 - val_loss: 0.6989 - val_accuracy: 0.5000 - 98ms/epoch - 2ms/step
# Epoch 9/30
# 44/44 - 0s - loss: 0.6969 - accuracy: 0.5078 - val_loss: 0.6974 - val_accuracy: 0.5000 - 92ms/epoch - 2ms/step
# Epoch 10/30
# 44/44 - 0s - loss: 0.6952 - accuracy: 0.5128 - val_loss: 0.6962 - val_accuracy: 0.5000 - 99ms/epoch - 2ms/step
# Epoch 11/30
# 44/44 - 0s - loss: 0.6944 - accuracy: 0.5043 - val_loss: 0.6955 - val_accuracy: 0.5139 - 121ms/epoch - 3ms/step
# Epoch 12/30
# 44/44 - 0s - loss: 0.6939 - accuracy: 0.5556 - val_loss: 0.6952 - val_accuracy: 0.5000 - 116ms/epoch - 3ms/step
# Epoch 13/30
# 44/44 - 0s - loss: 0.6933 - accuracy: 0.5349 - val_loss: 0.6957 - val_accuracy: 0.5000 - 134ms/epoch - 3ms/step
# Epoch 14/30
# 44/44 - 0s - loss: 0.6926 - accuracy: 0.5235 - val_loss: 0.6945 - val_accuracy: 0.5000 - 109ms/epoch - 2ms/step
# Epoch 15/30
# 44/44 - 0s - loss: 0.6909 - accuracy: 0.5556 - val_loss: 0.6945 - val_accuracy: 0.5000 - 102ms/epoch - 2ms/step
# Epoch 16/30
# 44/44 - 0s - loss: 0.6897 - accuracy: 0.5363 - val_loss: 0.6969 - val_accuracy: 0.5000 - 130ms/epoch - 3ms/step
# Epoch 17/30
# 44/44 - 0s - loss: 0.6881 - accuracy: 0.5207 - val_loss: 0.6948 - val_accuracy: 0.5000 - 125ms/epoch - 3ms/step
# Epoch 18/30
# 44/44 - 0s - loss: 0.6870 - accuracy: 0.5726 - val_loss: 0.6949 - val_accuracy: 0.5000 - 105ms/epoch - 2ms/step
# Epoch 19/30
# 44/44 - 0s - loss: 0.6853 - accuracy: 0.6909 - val_loss: 0.6941 - val_accuracy: 0.5105 - 116ms/epoch - 3ms/step
# Epoch 20/30
# 44/44 - 0s - loss: 0.6830 - accuracy: 0.5620 - val_loss: 0.7020 - val_accuracy: 0.5000 - 108ms/epoch - 2ms/step
# Epoch 21/30
# 44/44 - 0s - loss: 0.6820 - accuracy: 0.6125 - val_loss: 0.6932 - val_accuracy: 0.5139 - 107ms/epoch - 2ms/step
# Epoch 22/30
# 44/44 - 0s - loss: 0.6777 - accuracy: 0.5741 - val_loss: 0.6988 - val_accuracy: 0.5000 - 129ms/epoch - 3ms/step
# Epoch 23/30
# 44/44 - 0s - loss: 0.6758 - accuracy: 0.5890 - val_loss: 0.6950 - val_accuracy: 0.5122 - 110ms/epoch - 3ms/step
# Epoch 24/30
# 44/44 - 0s - loss: 0.6713 - accuracy: 0.6702 - val_loss: 0.6928 - val_accuracy: 0.5000 - 127ms/epoch - 3ms/step
# Epoch 25/30
# 44/44 - 0s - loss: 0.6683 - accuracy: 0.6660 - val_loss: 0.6942 - val_accuracy: 0.5139 - 114ms/epoch - 3ms/step
# Epoch 26/30
# 44/44 - 0s - loss: 0.6617 - accuracy: 0.6524 - val_loss: 0.6921 - val_accuracy: 0.5139 - 113ms/epoch - 3ms/step
# Epoch 27/30
# 44/44 - 0s - loss: 0.6578 - accuracy: 0.7265 - val_loss: 0.6951 - val_accuracy: 0.5139 - 106ms/epoch - 2ms/step
# Epoch 28/30
# 44/44 - 0s - loss: 0.6521 - accuracy: 0.6567 - val_loss: 0.7052 - val_accuracy: 0.5000 - 109ms/epoch - 2ms/step
# Epoch 29/30
# 44/44 - 0s - loss: 0.6477 - accuracy: 0.6396 - val_loss: 0.7021 - val_accuracy: 0.5174 - 129ms/epoch - 3ms/step
# Epoch 30/30
# 44/44 - 0s - loss: 0.6432 - accuracy: 0.6830 - val_loss: 0.6918 - val_accuracy: 0.5139 - 128ms/epoch - 3ms/step

# %%
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
y_pred = modele.predict(validation_filled)
predictions = np.argmax(y_pred,axis=1)

for i in range(len(predictions)):
    predictions[i] = predictions[i] - 1
    
true_labels = []
for i in y_rus_test:
    if(i=='NotSexist'):
        true_labels.append(0)
    else:
        true_labels.append(1)
    
print("Accuracy : ", np.mean(predictions == true_labels))
metrics.confusion_matrix(true_labels, predictions)
# Out:
# Accuracy :  0.5139372822299652
# array([[ 11, 276],
#        [  3, 284]])
