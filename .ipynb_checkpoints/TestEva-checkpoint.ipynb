# %% [markdown]
# ### TUTORIAL

# %%
import pandas as pd
import numpy as np
import csv
from sklearn.utils import Bunch
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDClassifier
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split


from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

from gensim.models import Word2Vec
import nltk
from gensim.models import KeyedVectors

from nltk.cluster import KMeansClusterer
from nltk.tokenize import word_tokenize
#nltk.download('punkt')
import numpy as np 

from sklearn import cluster
from sklearn import metrics

from tensorflow.keras.preprocessing.text import one_hot
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

import csv
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
categories = ["not_sexist", "sexist"]
#               2161           989

# %%
data = pd.read_csv("my_csv.csv",sep = ',')
data.columns = ['tweet', 'class']

X = data['tweet']
y = data['class']

X_train, X_test, y_train , y_test = train_test_split(X , y ,test_size=0.3)

# %% [markdown]
# ### Tokenizing text with scikit-learn

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
X_train_counts.shape
# Out:
# (2204, 11264)

# %%
count_vect.vocabulary_.get(u'femme')
# Out:
# 4014

# %% [markdown]
# ### From occurrences to frequencies

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (2204, 11264)

# %% [markdown]
# ### Training a classifier

# %%
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
docs_new = ["Les hommes c'est tous les mêmes", 'Il est étudiant.'] #marche pas du tout
X_new_counts = count_vect.transform(docs_new)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = clf.predict(X_new_tfidf)

for doc, category in zip(docs_new, predicted):
     print('%r => %s' % (doc, categories[category]))
# Out:
# "Les hommes c'est tous les mêmes" => not_sexist
# 'Il est étudiant.' => not_sexist

# %% [markdown]
# ### Building a pipeline

# %%
text_clf = Pipeline([
...     ('vect', CountVectorizer()),
...     ('tfidf', TfidfTransformer()),
...     ('clf', MultinomialNB()),
... ])
text_clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('clf', MultinomialNB())])

# %% [markdown]
# ### Evaluation of the performance on the test set

# %%
docs_test = X_test
predicted = text_clf.predict(docs_test)
np.mean(predicted == y_test)
# Out:
# 0.6984126984126984

# %% [markdown]
# ### SVM

# %%
text_clf = Pipeline([
...     ('vect', CountVectorizer()),
...     ('tfidf', TfidfTransformer()),
...     ('clf', SGDClassifier(loss='hinge', penalty='l2',
...                           alpha=1e-3, random_state=42,
...                           max_iter=5, tol=None)),
... ])
text_clf.fit(X_train, y_train)
predicted = text_clf.predict(docs_test)
np.mean(predicted == y_test)
# Out:
# 0.7534391534391535

# %%
print(metrics.classification_report(y_test, predicted,
...     target_names=categories))
# Out:
#               precision    recall  f1-score   support
#
#   not_sexist       0.77      0.91      0.83       644
#       sexist       0.68      0.43      0.52       301
#
#     accuracy                           0.75       945
#    macro avg       0.73      0.67      0.68       945
# weighted avg       0.74      0.75      0.73       945

# %%
metrics.confusion_matrix(y_test, predicted)
# Out:
# array([[584,  60],
#        [173, 128]], dtype=int64)

# %% [markdown]
# ### Parameter tuning using grid search

# %%
parameters = {
...     'vect__ngram_range': [(1, 1), (1, 2)],
...     'tfidf__use_idf': (True, False),
...     'clf__alpha': (1e-2, 1e-3),
... }

# %%
gs_clf = GridSearchCV(text_clf, parameters, cv=5, n_jobs=-1)

# %%
gs_clf = gs_clf.fit(X_train[:100], y_train[:100])
#ameliorer vecteur et algo et representation
#-> plus de poids sur les mots sexistes

# %%
example_1 = 'La femme'
example_2 = "L'homme"
example_3 = "La femme doit être dans la cuisine"

print(example_1 + "  => " + str(categories[gs_clf.predict([example_1])[0]]))
print(example_2 + "  => " + str(categories[gs_clf.predict([example_2])[0]]))
print(example_3 + "  => " + str(categories[gs_clf.predict([example_3])[0]]))
# Out:
# La femme  => not_sexist
# L'homme  => sexist
# La femme doit être dans la cuisine  => sexist

# %%
gs_clf.best_score_
# Out:
# 0.8099999999999999

# %%
for param_name in sorted(parameters.keys()):
     print("%s: %r" % (param_name, gs_clf.best_params_[param_name]))
# Out:
# clf__alpha: 0.01
# tfidf__use_idf: True
# vect__ngram_range: (1, 2)

# %% [markdown]
# ### Oversampling

# %%
# instantiating the random over sampler 
ros = RandomOverSampler()
# resampling X, y
X_ros, y_ros = ros.fit_resample(np.array(X_train).reshape(-1,1), y_train)# new class distribution 
print(Counter(y_ros))
# Out:
# Counter({1: 1516, 0: 1516})

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_ros.ravel())
X_train_counts.shape
# Out:
# (3032, 11264)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (3032, 11264)

# %%
clf = MultinomialNB().fit(X_train_tfidf, y_ros)
docs_new = ["y'a que les femmes qui pleurent", "C'est un homme."] 
X_new_counts = count_vect.transform(docs_new)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = clf.predict(X_new_tfidf)

for doc, category in zip(docs_new, predicted):
     print('%r => %s' % (doc, categories[category]))
        
text_clf = Pipeline([('vect', CountVectorizer()), ('tfidf', TfidfTransformer()), ('clf', MultinomialNB()),])
text_clf.fit(X_ros.ravel(), y_ros)


# resampling X, y
X_ros_test, y_ros_test = ros.fit_resample(np.array(X_test).reshape(-1,1), y_test)# new class distribution 
docs_test = X_ros_test.ravel()
predicted = text_clf.predict(docs_test)
np.mean(predicted == y_ros_test)
print("Accuracy : ", np.mean(predicted == y_ros_test))
metrics.confusion_matrix(y_ros_test, predicted)
# Out:
# "y'a que les femmes qui pleurent" => sexist
# "C'est un homme." => sexist
# Accuracy :  0.7360248447204969
# array([[402, 242],
#        [ 98, 546]], dtype=int64)

# %% [markdown]
# ### Undersampling

# %%
# instantiating the random over sampler 
ros = RandomUnderSampler()
# resampling X, y
X_ros, y_ros = ros.fit_resample(np.array(X_train).reshape(-1,1), y_train)# new class distribution 
print(Counter(y_ros))
# Out:
# Counter({0: 688, 1: 688})

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_ros.ravel())
X_train_counts.shape
# Out:
# (1376, 8003)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (1376, 8003)

# %%
clf = MultinomialNB().fit(X_train_tfidf, y_ros)
docs_new = ["y'a que les femmes qui pleurent", "C'est un homme."] 
X_new_counts = count_vect.transform(docs_new)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = clf.predict(X_new_tfidf)

for doc, category in zip(docs_new, predicted):
     print('%r => %s' % (doc, categories[category]))
        
text_clf = Pipeline([('vect', CountVectorizer()), ('tfidf', TfidfTransformer()), ('clf', MultinomialNB()),])
text_clf.fit(X_ros.ravel(), y_ros)


# resampling X, y
X_ros_test, y_ros_test = ros.fit_resample(np.array(X_test).reshape(-1,1), y_test)# new class distribution 
docs_test = X_ros_test.ravel()
predicted = text_clf.predict(docs_test)
print("Accuracy : ", np.mean(predicted == y_ros_test))
metrics.confusion_matrix(y_ros_test, predicted)
# Out:
# "y'a que les femmes qui pleurent" => sexist
# "C'est un homme." => sexist
# Accuracy :  0.7325581395348837
# array([[184, 117],
#        [ 44, 257]], dtype=int64)

# %% [markdown]
# ### Oversampling and Undersampling

# %%
over = RandomOverSampler(sampling_strategy=0.5)
under = RandomUnderSampler(sampling_strategy=0.8)

# %%
X_over, y_over = over.fit_resample(np.array(X_train).reshape(-1,1), y_train)
print(f"Oversampled: {Counter(y_over)}")
# Out:
# Oversampled: Counter({0: 1516, 1: 758})

# %%
# now to comine under sampling 
X_ros, y_ros = under.fit_resample(X_over, y_over)
print(f"Combined Random Sampling: {Counter(y_ros)}")
# Out:
# Combined Random Sampling: Counter({0: 947, 1: 758})

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_ros.ravel())
X_train_counts.shape
# Out:
# (1705, 9175)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (1705, 9175)

# %%
clf = MultinomialNB().fit(X_train_tfidf, y_ros)
docs_new = ["y'a que les femmes qui pleurent", "C'est un homme."]
X_new_counts = count_vect.transform(docs_new)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = clf.predict(X_new_tfidf)

for doc, category in zip(docs_new, predicted):
     print('%r => %s' % (doc, categories[category]))
        
text_clf = Pipeline([('vect', CountVectorizer()), ('tfidf', TfidfTransformer()), ('clf', MultinomialNB()),])
text_clf.fit(X_ros.ravel(), y_ros)


# resampling X, y
X_ros_test, y_ros_test = ros.fit_resample(np.array(X_test).reshape(-1,1), y_test)# new class distribution 
docs_test = X_ros_test.ravel()
predicted = text_clf.predict(docs_test)
print("Accuracy : ", np.mean(predicted == y_ros_test))
metrics.confusion_matrix(y_ros_test, predicted)
# Out:
# "y'a que les femmes qui pleurent" => sexist
# "C'est un homme." => sexist
# Accuracy :  0.7308970099667774
# array([[244,  57],
#        [105, 196]], dtype=int64)

# %% [markdown]
# ### Word Embedding using Doc2Vec

# %% [markdown]
# ###### 1st Step : Getting cleaned data

# %%
data = pd.read_csv("my_csv_clean.csv",sep = ',') #we got that csv after running the Text Preprocessing file
data.columns = ['tweet', 'class']
    

X = data['tweet']
y = data['class'] 

X_train, X_test, y_train , y_test = train_test_split(X , y ,test_size=0.3)

# %% [markdown]
# ###### 2nd step : Keeping a tokenized version of the sentences and the corresponding categories

# %%
X_tokenized = []
y_tokenized = []

for sentence in X_train:
    X_tokenized.append(word_tokenize(sentence))    
    
for cat in y_train:
    y_tokenized.append(cat)

# %% [markdown]
# ###### 3rd step : Defining a cosine function to compute the similaity between two vectors

# %%
def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

# %% [markdown]
# ###### 4th step : Building a tagged sentence corpus

# %%
tagged_data = [TaggedDocument(d, [i]) for i, d in enumerate(X_tokenized)]
tagged_data
# Out:
# [TaggedDocument(words=['travail', 'domicile', 'jbl', 'charge', '3', 'enceinte', 'étanche', 'autonome', 'mais', 'aurait', 'pu', 'être', 'meilleur'], tags=[0]),
#  TaggedDocument(words=['fabrique', 'balancetonporc', 'si', 'toi', 'aussi', 'veux', 'être', 'victime', 'du', 'vilain', 'sexisme', 'sois', 'invitée', 'pr', 'parler', 'de', 'politique', 'affuble', 'toi', 'dune', 'tenue', 'affriolante', 'pour', 'provoquer', 'réactions', 'accuser', 'ensuite', 'sexismeordinaire', 'aurore', 'bergé', 'atelle', 'lumière', 'tous', 'ls', 'étages'], tags=[1]),
#  TaggedDocument(words=['1ère', 'fois', 'me', 'suis', 'faite', 'siffler', 'dans', 'rue', 'javais', '14', 'ans', 'mecs', '30', 'de', '+', 'sentiment', 'de', 'gêne', 'dhumiliation', 'balancetonporc'], tags=[2]),
#  TaggedDocument(words=['audio', 'véronique', 'cloutier', 'explique', 'absence', 'mouvements', 'comme', 'moiaussi', '|', 'jdm'], tags=[3]),
#  TaggedDocument(words=['brexit', 'chambre', 'lords', 'inflige', 'nouveau', 'camouflet', 'theresa', 'may', 'ue'], tags=[4]),
#  TaggedDocument(words=['retour', 'de', 'bâton', 'après', 'balancetonporc', 'colletadindeautribunal', 'via', '@', 'bvoltaire'], tags=[5]),
#  TaggedDocument(words=['suis', 'vraiment', 'genre', 'de', 'fille', 'qui', 'marque', 'esprits', 'ironie'], tags=[6]),
#  TaggedDocument(words=['«', 'les', 'calacs', 'rapportent', 'forte', 'augmentation', 'appels', 'depuis', 'quelques', 'semaines', 'l', '’', 'impunité', 'n', '’', 'est', 'plus', 'acquise', '»', 'polqc', 'moiaussi'], tags=[7]),
#  TaggedDocument(words=['j', '’', 'ai', 'senti', 'partie', 'de', 'moi', 'disparaître', 'partie', 'de', 'moi', 'nai', 'jamais', 'retrouvée', 'témoignage', 'glaçant', 'de', 'lactrice', 'de', 'série', 'westworld', 'evan', 'rachel', 'wood', 'victime', 'de', 'viols'], tags=[8]),
#  TaggedDocument(words=['angela', 'merkel', 'qui', 'retourne', 'veste', 'sur', 'syrie', 'annonce', 'lallemagne', 'ne', 'participera', 'aucune', 'coalition', 'de', 'frappe', 'syrie', 'doit', 'on', 'conclure', 'craint', 'vladimir', 'putin'], tags=[9]),
#  TaggedDocument(words=['rabat', 'maroc', 'ou', 'volonté', 'individuelle', 'de', 'porter', 'voile', 'comme', 'disait', 'lautre', 'patriarcat', 'intégré', 'sexisme'], tags=[10]),
#  TaggedDocument(words=['brexit', 'theresa', 'may', 'assure', 'qu', '’', 'un', 'accord', 'sur', 'droit', 'expatriés', 'est', '«', 'portée', 'de', 'main', '»'], tags=[11]),
#  TaggedDocument(words=['monique', 'simard', 'parcours', 'de', 'féministre', 'engagée', 'elle', 'fait', 'bilan', 'avec', 'nous', 'alors', 'scandales', 'secouent', 'monde', 'arts', 'moiaussi', 'etmaintenant', 'rdi2460'], tags=[12]),
#  TaggedDocument(words=['conférence', 'sur', 'sexisme', 'sport', 'sexisme', 'sport', 'bravo', '@', 'bbarbusse', 'women', 'il', 'du', 'boulot', 'pour', 'équilibrer', 'hein', 'egalitefh', 'autant', 'sy', 'mettre', 'fond', 'toutes', 'tous', 'ça', 'sera', 'plus', 'rapide', 'comme', 'quand', 'on', 'fait', 'ménage', 'apres', '21', 'siècles', 'de', 'vie', 'commune'], tags=[13]),
#  TaggedDocument(words=['@', 'malikmahieu', 'différence', 'cest', 'christian', 'grey', 'nexiste', 'pas', 'cest', 'acteur', 'payé', 'pour', 'faire', 'semblant', 'ce', 'font', 'acteurs', 'est', 'impossible', 'dans', 'vraie', 'vie', 'alors', 'balancetonporc', 'ce', 'sont', 'mecs', 'réels', 'qui', 'veulent', 'faire', 'vrai', 'ce', 'quils', 'voient', 'dans', 'films'], tags=[14]),
#  TaggedDocument(words=['e1matin', '@', 'zappette', 'nadiadaam', 'ça', 'fait', 'plaisir', 'dentendre', 'par', 'journaliste', 'ce', 'quon', 'pense', 'de', 'ces', 'pubs', 'c', 'du', 'sexisme', 'qui', 'fait', 'partie', 'depuis', 'décennies'], tags=[15]),
#  TaggedDocument(words=['misstwitter', 'elle', 'me', 'fout', 'simplement', 'gerbe', 'votre', 'manœuvre', 'grossière', 'pour', 'vous', 'rincer', 'lœil', 'vous', 'êtes', 'pathétiques'], tags=[16]),
#  TaggedDocument(words=['super', 'journée', 'pour', 'commencer', 'semaine', 'quoi', 'de', 'mieux', 'de', 'retrouver', 'sur', 'même', 'table', 'midi', 'quune', 'fille', 'quon', 'déteste', 'ironie'], tags=[17]),
#  TaggedDocument(words=['8', 'mars', 'france2', 'propose', 'émissions', 'sur', 'femmes', 'toute', 'nuit', 'cest', 'bien', 'demain', 'on', 'bosse', '8mars', 'féminisme', 'ironie'], tags=[18]),
#  TaggedDocument(words=['unfilmpourlesfachos', 'quand', 'aryen', 'rencontre', 'salope'], tags=[19]),
#  TaggedDocument(words=['moteur', 'franco', 'quoi', 'angela', 'merkel', '’', 's', 'party', 'slams', 'eu', '‘', 'monetary', 'fund', '’', 'plan', 'in', 'blow', 'to', 'macron', 'via', '@', 'financialtimes'], tags=[20]),
#  TaggedDocument(words=['françois', 'fillon', 'fait', 'huer', 'christiane', 'taubira', 'pertuis', 'dans', 'vaucluse', 'il', 'est', 'pitoyable'], tags=[21]),
#  TaggedDocument(words=['balancetonporc', 'voil', 'jlai', 'fais'], tags=[22]),
#  TaggedDocument(words=['ce', 'photographe', 'libanais', 'inverse', 'rôles', 'dans', 'pubs', 'sexistes', 'années', '50', 'via', '@', 'magazinecheek', 'pub', 'sexisme', 'stéréotype'], tags=[23]),
#  TaggedDocument(words=['@', 'sebastienm', '@', 'auroreberge', 'quiche', 'ne', 'connais', 'pas', 'mot', 'démocratie'], tags=[24]),
#  TaggedDocument(words=['bonne', 'idée', 'après', 'moiaussi', 'plusjamais', '2018', 'bravo', 'pour', 'ce', 'beau', 'segment', 'sensible', 'intelligent', 'sur', 'consentement', 'mammouth2017', '@', 'telequebec'], tags=[25]),
#  TaggedDocument(words=['signature', 'de', 'charte', 'par', 'tftc', '@', 'cometentreprise', 'du', 'collectif', 'ensemblecontrelesexisme', 'avec', '22', 'autres', 'organisations', 'engagées', 'dans', 'tous', 'domaines', 'où', 'niche', 'sexisme'], tags=[26]),
#  TaggedDocument(words=['seule', 'avoir', 'loupé', 'coche', 'lors', 'de', '2', 'élections', 'de', 'suite', 'cest', 'quand', 'même', 'ségolène', 'royal', 'ni', 'présidente', 'ni', 'femme', 'de', 'président'], tags=[27]),
#  TaggedDocument(words=['angela', 'merkel', 'rules', 'out', 'german', 'military', 'action', 'in', 'syria'], tags=[28]),
#  TaggedDocument(words=['nouvelle', 'plus', 'importante', 'de', '2017', 'mouvement', 'de', 'moiaussi', 'ce', 'mouvement', 'totalement', 'influencé', 'tout', 'personne', 'dans', 'monde', 'femmes', 'hommes', 'personnes', 'lgbtq', 'fls2761'], tags=[29]),
#  TaggedDocument(words=['@', 'teobaldo', 'blanche', 'grasse', 'comme', 'angela', 'merkel', 'cest', 'du', 'très', 'haut', 'niveau'], tags=[30]),
#  TaggedDocument(words=['@', 'daben59', '@', 'lehuffpost', 'ouiiiiii', 'tristesse', 'tt', 'ca', 'balancetonporc', 'changera', 'choses', 'qd', 'enfin', 'de', 'nos', 'politiciens', 'mettra', 'pieds', 'ds', 'plat', 'quil', 'ny', 'aura', 'plus', 'de', 'justice', '2', 'vitesses'], tags=[31]),
#  TaggedDocument(words=['c', '’', 'est', 'qui', 'qui', 'gros', 'homophobe', 'décidément', 'après', 'avoir', 'comparé', 'balancetonporc', 'délation', '2nde', 'guerre', 'mondiale', '«', 'cest', 'grosse', '«', 'tarlouze', 'association', 'saisit', 'csa', 'après', 'dérapage', 'de', 'joeystarr', 'onpc', '»'], tags=[32]),
#  TaggedDocument(words=['après', '1', 'an', 'au', 'pouvoir', '«', 'vision', 'précise', 'de', 'theresa', 'may', 'sur', 'brexit', 'reste', 'pratiquement', 'inconnue', '»', '@', 'canalbernard'], tags=[33]),
#  TaggedDocument(words=['«', 'campagne', 'de', 'dénonciation', 'moiaussi', 'mis', 'nouvelle', 'fois', 'évidence', 'l', '’', 'ampleur', 'du', 'phénomène', 'or', 'il', 'faut', 'rappeler', 'qu', '’', 'à', 'peine', '5', 'femmes', 'agressées', 'portent', 'plainte', 'seulement', '3', 'plaintes', 'sur', '1000', 'soldent', 'par', 'condamnation', '»'], tags=[34]),
#  TaggedDocument(words=['donald', 'trump', 'thérésa', 'may', 'emmanuel', 'macron', 'lempereur', 'femme', 'petit', 'prince', 'nonàlaguerre', 'feteamacron'], tags=[35]),
#  TaggedDocument(words=['ne', 'suis', 'pas', 'pour', 'plaire', 'suis', 'pour', 'faire', 'ce', 'nous', 'faisons', 'ne', 'plaît', 'pas', 'tous', 'ceux', 'qui', 'vivent', 'sur', 'mensonges', 'agitent', 'peur', 'croiserai', 'samedi', 'regarderai', 'dans', 'yeux'], tags=[36]),
#  TaggedDocument(words=['actualités', 'du', 'numérique', 'genrimages', 'sexisme', 'via', '@', 'pearltrees'], tags=[37]),
#  TaggedDocument(words=['harcèlement', 'linitiatrice', 'du', 'mouvement', 'balancetonporc', 'attaquée', 'pour', 'diffamation', 'via', '@', 'europe1'], tags=[38]),
#  TaggedDocument(words=['eliza', 'dushku', 'aurait', 'été', 'agressée', 'sur', 'plateau', 'de', '«', 'vrai', 'mensonge', '»', '|', 'jdq', 'metoo', 'moiaussi'], tags=[39]),
#  TaggedDocument(words=['ségolène', 'royal', 'au', 'meeting', 'de', 'rennes', 'avec', 'françois', 'hollande', 'cette', 'femme', 'est', 'quand', 'même', 'digne', 'classe', 'respect'], tags=[40]),
#  TaggedDocument(words=['gros', 'décalage', 'entre', 'discours', 'du', '1er', 'mai', 'de', '@', 'sophiewilmes', 'pour', 'mr', 'qui', 'donne', 'message', 'positif', 'pour', 'booster', 'présence', 'femmes', 'politique', '@', 'ericmassin', 'pour', 'ps', 'qui', 'parle', 'dune', 'femme', 'politique', 'traitant', 'de', 'salope', '@', 'taqu1caro', 'equity', 'balancetonmassin'], tags=[41]),
#  TaggedDocument(words=['cest', 'impressionnant', 'comme', 'grand', 'mère', 'défend', 'sexisme', 'mode', 'cest', 'normal', 'femmes', 'restent', 'maison', 'cest', 'leur', 'rôle'], tags=[42]),
#  TaggedDocument(words=['@', 'aquatennens', '@', 'lcp', 'ça', 'dépend', 'ya', 'du', 'frédéric', 'haziza', 'dedans', 'naan', 'parce', 'dès', 'vois', 'haziza', 'hop', 'jéteins', 'tv', 'ou', 'change', 'de', 'chaine', 'boycottlcp', 'hazizasuspension', 'metoo', 'balancetonporc'], tags=[43]),
#  TaggedDocument(words=['tout', 'travail', 'dangela', 'merkel', 'de', 'lallemagne', 'été', 'balayé', 'par', 'immigrationnisme', 'non', 'nous', 'ne', 'pouvons', 'pas', 'remercier', 'sur', 'ce', 'sujet', 'qui', 'est', 'grave', 'erreur', 'de', 'gestion', 'politique', 'envers', 'peuples', 'deurope'], tags=[44]),
#  TaggedDocument(words=['sexisme', 'deneuve', 's', '’', 'explique', 'présente', '«', 'excuses', '»', 'aux', 'victimes'], tags=[45]),
#  TaggedDocument(words=['christine', 'lagarde', 'ump', 'française', 'élue', 'femme', 'plus', 'influente', 'du', 'monde', 'par', 'vanity', 'fair', 'juppé', 'niche'], tags=[46]),
#  TaggedDocument(words=['collègue', 'végétarienne', 's', '’', 'est', 'vue', 'recevoir', 'ce', 'gif', 'de', 'ancien', 'patron', 'avec', 'commentaire', '«', 'c', '’', 'est', 'comme', 'ça', 'manges', 'carottes', 'lol', '»', 'balancetonporc'], tags=[47]),
#  TaggedDocument(words=['communique', 'de', 'presse', 'est', 'sorti', 'de', 'presse', 'moiaussi', 'canada'], tags=[48]),
#  TaggedDocument(words=['guyane', 'christiane', 'taubira', 'sur', 'barrage', 'si', 'élus', 'considèrent', 'peux', 'aider', 'ferai', 'très', 'volontiers'], tags=[49]),
#  TaggedDocument(words=['@', 'jeanmi2p1', 'est', 'ouvertement', 'grossophobe', 'il', 'me', 'compare', 'femme', 'enceinte', 'quand', 'me', 'prélasse', 'sur', 'chaise', 'balancetonporg'], tags=[50]),
#  TaggedDocument(words=['femme', 'elle', 'va', 'etre', 'bien', 'plus', 'tard', 'coffre', 'argent', 'comme', 'enculer', 'fais', 'pas', 'mek', 'qui', 'dépense', 'pour', 'épater', 'vieille', 'pute'], tags=[51]),
#  TaggedDocument(words=['pour', 'christine', 'lagarde', 'l', '’', 'avenir', 'monétaire', 'est', 'au', 'bitcoin', 'ça', 'va', 'arriver', 'plus', 'vite', 'quon', 'ne', 'pense'], tags=[52]),
#  TaggedDocument(words=['segoleneroyal', 'nommée', 'ambassadrice', 'pour', 'pôles', 'arctique', 'amp', 'antarctique', 'manchots', 'manifestent', '500', 'selon', 'police', '50000', 'selon', 'org'], tags=[53]),
#  TaggedDocument(words=['j', 'objectif', 'c', 'est', 'de', 'salir', 'l', 'membre', 'du', 'gouvernement', 'femme', 'qui', 'accuse', 'gérald', 'darmanin', 'c', 'est', 'vendue', 'qui', 'cherche', 'abattre', 'homme', 'point', 'ce', 'n', 'est', 'pas', 'digne', 'de', 'tout', 'ceux', 'qui', 'sont', 'derrière', 'cette', 'comédie', 'ls', 'opposants', 'ne', 'sont', 'ps', 'étrangers', 'ce', 'film👎'], tags=[54]),
#  TaggedDocument(words=['demain', 'femme', 'seule', 'ségolène', 'royal', 'primaires', 'royal2012'], tags=[55]),
#  TaggedDocument(words=['mise', 'jour', 'concernant', 'scandale', 'windrush', 'gouvernement', 'soutien', 'theresa', 'may', 'après', 'démission', 'damber', 'rudd', 'ministre', 'de', 'lintérieur', 'il', 'faut', 'dire', 'may', 'est', 'fâcheuse', 'posture', 'cet', '«', 'environnement', 'hostile', '»', 'cest', 'elle', 'qui', 'créé…'], tags=[56]),
#  TaggedDocument(words=['on', 'vous', 'prépare', 'colloque', 'très', 'complet', 'avec', 'collectif', 'ensemblecontrelesexisme', '22', 'organisations', 'qui', 'représentent', 'toutes', 'causes', 'secteurs', 'd', '’', 'activités', 'inscrivezvous', 'nombreuses', 'surtout', 'nombreux', 'journée', 'présence', 'de', '@', 'marleneschiappa', '@', 'laurossignol'], tags=[57]),
#  TaggedDocument(words=['ben', 'voyons', 'donc', 'voir', 'vous', 'pensez', 'comme', 'c', '’', 'est', 'femme', 'dans', 'mouvement', 'moiaussi', 'savent', 'tres', 'bien', 'différence', 'entre', 'deux', 'chapeau', 'ces', 'femmes'], tags=[58]),
#  TaggedDocument(words=['personnalité', '@', 'time', 'ces', 'femmes', 'qui', 'ont', 'dit', 'tout', 'haut', 'atrocités', 'vécues', 'durant', 'leur', 'vie', 'metoo', 'moiaussi', 'balancetonporc', 'personoftheyear2017'], tags=[59]),
#  TaggedDocument(words=['vraiment', 'politique', 'demain', 'soir', '@', 'alancelin', 'léquipe', 'du', 'média', 'vous', 'donne', 'rendezvous', 'pour', 'nouveau', 'numéro', 'de', 'vraimentpolitique', 'après', 'metoo', 'balancetonporc', 'où', 'sommes', 'nous', 'rendezvous', 'demain', 'après', 'lejournal'], tags=[60]),
#  TaggedDocument(words=['@', 'foismarina', 'ne', 'suis', 'pas', 'france', 'mais', 'il', 'paraît', 'vous', 'avez', 'dit', 'du', 'bien', 'de', 'balancetonporc', 'merci', 'vous', 'ça', 'vous', 'serve', 'positivement', 'vous', 'surtout', 'vos', 'proches', 'cordialement'], tags=[61]),
#  TaggedDocument(words=['sous', 'prétexte', 'présidente', 'de', 'commission', 'lois', '@', 'yaelbraunpivet', 'est', 'femme', '@', 'robinreda', 'qualifie', 'rappels', 'au', 'règlement', 'de', '«', 'maternels', '»', 'auraitil', 'répliqué', 'de', 'même', 'manière', 'homme', 'plus', 'âgé', '«', 'vous', 'avez', 'l', '’', 'âge', 'd', '’', 'être', 'père', '»', 'sexisme'], tags=[62]),
#  TaggedDocument(words=['tenirsespromesses', 'pour', 'clore', 'cette', 'semaine', 'de', 'pénitence', 'ff', '@', 'xorizo', '@', 'pjunjour', '@', 'barondepontault', '@', 'movelikejaeger', '@', 'violentpolicier', '@', 'btankraide', '@', 'sardevrk', '@', 'yannpiz', 'vous', 'prouvez', 'même', 'fdo', 'ont', 'cerveau'], tags=[63]),
#  TaggedDocument(words=['après', 'lhomophobie', 'haine', 'femmes', 'félicitations', '@', 'olivierrimmel', 'vous', 'venez', 'de', 'gagner', 'point', 'con', 'du', 'jour', 'balancetonporc'], tags=[64]),
#  TaggedDocument(words=['solidarité', 'avec', 'celles', 'qui', 'ont', 'libéré', 'leur', 'parole', 'avec', 'moiaussi', 'centaines', 'de', 'québécoises', 'de', 'tous', 'horizons', 'disent', 'aujourdhui', 'etmaintenant'], tags=[65]),
#  TaggedDocument(words=['mois', 'avant', 'coupe', 'du', 'monde', 'domicile', 'tout', 'reste', 'faire', 'match', 'france', 'italie', 'direct', 'du', 'vélodrome\u200b', 'de', 'marseille', 'cest', 'ce', 'soir', '20h50', 'allez', 'bleues', '@', 'equipedefrance', 'frita'], tags=[66]),
#  TaggedDocument(words=['«', 'nous', 'avons', 'calendrier', 'intense', '2018', 'car', 'c', '’', 'est', 'début', 'de', 'quinquennat', 'qu', '’', 'il', 'faut', 'faire', 'passer', 'réformes', 'importantes', '»', 'legrandsoirweekend', '@', 'lci'], tags=[67]),
#  TaggedDocument(words=['soutien', '@', 'auroreberge', 'après', 'idioties', 'dites', 'encontre', 'après', 'passage', 'l', '’', 'émission', 'slt', 'c', '’', 'est', 'femme', 'donc', 'on', 'critique', 'apparence', 'au', 'lieu', 'd', '’', 'écouter', 'déclarations', 'continuons', 'dénoncer', 'comportements', 'sur', 'réseaux', 'sociaux', 'agissons', 'pr', 'l', '’', 'egalitefh'], tags=[68]),
#  TaggedDocument(words=['pays', 'd', '’', 'angela', 'merkel', 'possède', 'bagatelle', 'de', '3400', 'tonnes', 'd', '’', 'or', 'équivalant', '117', 'milliards', 'd', '’', 'euros', 'via', '@', 'otimbicom'], tags=[69]),
#  TaggedDocument(words=['groupe', 'de', 'réflexion', 'sur', 'sexisme', 'avant', 'louverture', 'de', 'lag', 'mimandat', 'de', '@', 'lafnek', 'avec', '@', 'alicefnek', 'amp', '@', 'nassimfage', 'pcjs', 'cc', '@', 'lafage'], tags=[70]),
#  TaggedDocument(words=['france', 'enseignant', 'est', 'condamné', '18', 'mois', 'de', 'prison', 'avec', 'sursis', 'pour', 'avoir', 'eu', 'liaison', 'avec', 'élève', 'de', '14', 'ans', '@', 'courduquebec', '@', 'isabellericher', 'moiaussi'], tags=[71]),
#  TaggedDocument(words=['aujourdhui', 'réagir', 'contre', 'féminisme', 'cest', 'réactionnaire', 'mais', 'dénoncer', 'dérives', 'dans', 'féminisme', 'théoriedugenre', 'mariagepourtous', 'pma', 'gpa', 'cest', 'sortir', 'du', 'conservatisme', 'feministe', 'vouloir', 'faire', 'progresser', 'notre', 'société'], tags=[72]),
#  TaggedDocument(words=['selon', 'canard', 'enchaîné', 'sarkozy', 'aurait', 'dit', 'wauquiez', 'beaucoup', 'de', 'monde', 'me', 'disait', 'nétais', 'quune', 'grosse', 'merde', 'aujourdhui', 'nai', 'dautre', 'choix', 'de', 'penser', 'comme', 'eux', 'il', 'paraît', 'as', 'ambitions', 'présidentielles', 'si', 'jétais', 'toi', 'trouverais', 'autre', 'métier'], tags=[73]),
#  TaggedDocument(words=['marc', 'gaboury', 'propriétaire', 'de', 'boutique', 'de', 'noël', 'québec', 'sur', 'rue', 'buade', 'dans', 'vieuxquébec', 'balancetonporc', 'yqb', 'harcelement'], tags=[74]),
#  TaggedDocument(words=['@', 'jeremstar', '«', 'ne', 'suis', 'pas', 'violeur', 'mère', 'est', 'femme', '»', 'balancetonporc', 'de', 'rien', 'malaise', '–', 'jeremstar', 'palpe', 'poitrine', 'd', '’', 'une', 'jeune', 'femme', 'public', 'sur', 'snapchat', '“', 'je', 'ne', 'te', 'permet', 'pas', '”', 'il', 'continue', 'l', '’', 'humilie'], tags=[75]),
#  TaggedDocument(words=['flash', 'lallemagne', 'assure', 'ne', 'participera', 'pas', 'frappe', 'contre', 'syrie', 'de', 'même', 'canada', 'angela', 'merkel', 'affirme', 'toutefois', 'quil', 'paraît', 'évident', 'gouvernement', 'syrien', 'na', 'pas', 'détruit', 'toutes', 'armes', 'chimiques', 'médias', 'allemands', 'assad'], tags=[76]),
#  TaggedDocument(words=['ségolène', 'royal', 'va', 'devenir', 'ambassadrice', 'de', 'france', 'pour', 'pôles', 'arctique', 'antarctique', 'jai', 'accepté', 'ditelle', 'sur', '@', 'lci', 'calvi'], tags=[77]),
#  TaggedDocument(words=['moi', 'qui', 'pensais', 'france', 'pays', 'de', 'liberté', 'dégalité', 'oups', 'merci', 'de', 'mavoir', 'appris', 'ce', 'quest', 'être', 'femme'], tags=[78]),
#  TaggedDocument(words=['alerte', '🎟️la', 'billetterie', 'du', 'match', 'france', 'finlande', 'qui', 'déroulera', '14', 'février', '2018', '@', 'brestarena', 'ouvrira', 'demain', '10h00', 'soyez', 'premiers', 'acheter', 'vos', 'places', 'pour', 'supporter', 'bleues', 'gofrance'], tags=[79]),
#  TaggedDocument(words=['véronique', 'cloutier', 'explique', 'pourquoi', 'elle', 'nest', 'pas', 'sortie', 'publiquement', 'pour', 'mouvement', 'moiaussi'], tags=[80]),
#  TaggedDocument(words=['quand', 'féministe', 'épargne', 'judéosioniste', 'sénatrice', 'rossignol', 'accorde', 'interview', 'lagresseur', 'sexuel', 'présumé', 'haziza', 'cc', '@', 'frhaz', '@', 'laurossignol', '@', 'michelzer', '@', 'sdjlcp', '@', 'memalouines', '@', 'teamisaattard', '@', 'fderugy', '@', 'marleneschiappa', '@', 'manuelvalls', '@', 'adevillaines'], tags=[81]),
#  TaggedDocument(words=['balancetonporc', '1', 'policier', 'de', '32ans', 'été', 'mis', 'examen', 'puis', 'écroué', 'pr', 'viols', 'sur', 'mineur', 'détention', 'd', '’', 'images', 'pédopornographiques', 'ce', 'soir', 'versailles', 'il', 'est', 'soupçonné', 'd', '’', 'avoir', 'violé', 'agressé', 'sexuellement', '7', 'enfants', 'âgés', 'de', '2', '8', 'ans', 'entre', '2012', '2018'], tags=[82]),
#  TaggedDocument(words=['si', 'ça', 'avait', 'été', 'meuf', 'elle', 'aurait', 'crier', 'au', 'harcèlement', 'mode', 'balancetonporc'], tags=[83]),
#  TaggedDocument(words=['genderscan2017', 'enquête', 'sur', 'labsence', 'dégalité', 'femmes', 'hommes', '=gt', '18', 'juillet', 'france', 'sexiste'], tags=[84]),
#  TaggedDocument(words=['expotwitter', 'dans', 'locaux', 'de', '@', 'twitterfrance', '2017', 'tweets', 'cest', 'entre', 'autre', 'starwars8', 'balancetonporc', 'paris2024', 'election2017', 'petite', 'préférence', 'pour', 'penuriebeurre', 'poke', '@', 'albanmartin', '@', 'arielstraboni', '@', 'thedarkpixel'], tags=[85]),
#  TaggedDocument(words=['soirée', 'foot', '100', 'filles', 'au', 'vélodrome', 'clientes', 'invitées', 'collaboratrices', 'sont', 'données', 'rdv', 'lagence', 'crédit', 'agricole', 'de', 'grand', 'pavois', 'pour', 'match', 'de', 'léquipe', 'féminine', 'de', 'france', 'face', 'litalie', 'allez', 'bleues', '@', 'tousuncotefoot', '@', 'creditagricole'], tags=[86]),
#  TaggedDocument(words=['quand', 'vois', 'hommes', 'de', 'gauche', 'faire', 'traiter', 'de', 'sexiste', 'me', 'dis', 'alors', 'questce', 'ça', 'fait', 'de', 'subir', 'linfamie', 'quon', 'promeut'], tags=[87]),
#  TaggedDocument(words=['campagne', 'moiaussi', 'divise', 'femmes', 'france'], tags=[88]),
#  TaggedDocument(words=['38', 'jimmy', 'qui', 'met', 'main', 'balancetonporc'], tags=[89]),
#  TaggedDocument(words=['europe', 'emmanuel', 'macron', 'va', 'tenter', 'de', 'convaincre', 'angela', 'merkel', 'de', 'passer', 'vitesse', 'supérieure', 'macron', 'berlin', 'europe', 'angelamerkel'], tags=[90]),
#  TaggedDocument(words=['@', 'thefullmode', '@', 'carolinedehaas', '@', 'libe', 'oui', 'avis', 'ceci', 'caractérise', 'encore', 'plus', 'nettement', 'fait', 'elle', 'ne', 'pouvait', 'pas', 'ne', 'pas', 'signer', 'tribunedumonde', 'sexisme', 'misogynie'], tags=[91]),
#  TaggedDocument(words=['franor', 'fin', 'de', 'match', 'elles', 'ont', 'bien', 'méritées', 'leur', 'victoire', 'bravo', 'bleues', '👏🏆championnesdumonde'], tags=[92]),
#  TaggedDocument(words=['lindépendance', 'version', 'lemedia', 'leçon', 'de', 'journalisme', '😂😂😂'], tags=[93]),
#  TaggedDocument(words=['@', 'finge', 'signe', 'charte', 'du', 'collectif', 'ensemblecontrelesexisme', 'pour', 'poursuivre', 'mobilisation', 'sexismepasnotregenre'], tags=[94]),
#  TaggedDocument(words=['mouvements', 'récents', 'de', 'libération', 'de', 'parole', 'de', 'femme', 'metoo', 'balancetonporc', 'doivent', 'être', 'entendus', 'même', 'portés', 'exemple', 'par', 'l', '’', 'ensemble', 'de', 'classe', 'politique', 'ils', 'demandent', 'donc', 'classe', 'politique', 'tout', 'point', 'exemplaire', 'vousvoyeztrèsbiendequoijeveuxparler'], tags=[95]),
#  TaggedDocument(words=['mai', '68', 'si', 'tout', 'avait', 'commencé', 'avant…', 'madame', 'inter', 'féministe', 'v', '@', 'radiofanch'], tags=[96]),
#  TaggedDocument(words=['@', 'nhulot', 'ohcomment', 'vous', 'dire', 'votre', 'interview', 'défense', 'gout', 'amer', 'même', 'tactique', 'fillon', 'avec', 'femme', 'famille', 'c', 'est', 'gênant'], tags=[97]),
#  TaggedDocument(words=['tumblr', 'ironie', 'fille', 'dérision', 'allez', 'découvrir'], tags=[98]),
#  TaggedDocument(words=['pote', 'moi', 'cest', 'fait', 'claque', 'fesses', 'soirée', 'balancetonporc'], tags=[99]),
#  TaggedDocument(words=['macron', 'berlin', '@', 'fredroder', 'emmanuel', 'macron', 'angela', 'merkel', 'doivent', 'garder', 'tête', 'l', '’', 'avenir', 'de', 'l', '’', 'europe', 'passera', 'aussi', 'par', 'l', '’', 'afrique', 'cela', 'doit', 'refléter', 'dans', 'prochain', 'budget', 'européen', 'mff2018'], tags=[100]),
#  TaggedDocument(words=['ai', 'croisé', 'femme', 'dune', 'cinquante', 'dannées', 'dans', 'métro', 'elle', 'dun', 'indicible', 'charme', 'avec', 'cheveux', 'poivre', 'sel', 'quelques', 'sourires', 'partagés', 'jai', 'osé', 'bonne', 'journée', 'au', 'sortir', 'du', 'métro', 'sourires', 'tt', 'nest', 'pas', 'perdu', 'dans', 'ce', 'climat', 'hystérique', 'sexisme', 'harcellement'], tags=[101]),
#  TaggedDocument(words=['«', 'attention', 'monier', '»', 'enquête', 'sur', 'lexponte', 'de', 'france', '2', 'accusé', 'de', 'harcèlement', 'sexuel', 'via', '@', 'paulaveline'], tags=[102]),
#  TaggedDocument(words=['quand', 'votre', 'femme', 'naime', 'pas', 'ce', 'vous', 'lui', 'faite', 'elle', 'vous', 'dit', 'ou', 'sinon', 'elle', 'va', 'voire', 'ailleurs', 'bain', 'c', 'est', 'pareil', 'pir', 'biensur', 'ironie'], tags=[103]),
#  TaggedDocument(words=['ayyya', 'gauchiasses', 'qui', 'ragent', 'voir', 'jolie', 'fille', 'soucier', 'de', 'futur', 'ça', 'vous', 'change', 'trans', 'cheveux', 'vert', 'autre', 'fumeur', 'de', 'beuh', 'bande', 'de', 'salope', 'unfilmpourlesfachos'], tags=[104]),
#  TaggedDocument(words=['@', 'valeurs', 'ah', 'ça', 'va', 'vraiment', 'mal', 'encore', 'parole', 'de', 'trop', 'flagellation', 'immédiate', 'heureusement', 'supplice', 'de', 'roue', 'nexiste', 'plus', 'catherine', 'deneuve', 'hier', 'cest', 'pas', 'prêt', 'de', 'sarrêter'], tags=[105]),
#  TaggedDocument(words=['cest', 'quand', 'même', 'belle', 'femme', 'ségolène', 'royal', 'mais', 'laurence', 'ferrari', 'mis', 'trop', 'de', 'fond', 'de', 'teint', 'tf1', 'journal'], tags=[106]),
#  TaggedDocument(words=['toutes', 'ces', 'remarques', 'peu', 'sexistes', 'pour', '@', 'agatheauproux', 'ne', 'sont', 'pour', 'affirmer', 'balancetonporc', 'vous', 'frustré', 'babaoke'], tags=[107]),
#  TaggedDocument(words=['nouveau', 'bréviaire', '«', 'délation', '»', '«', 'séduction', 'française', '»', 'comment', 'répondre', 'aux', 'objections', 'après', 'balancetonporc', 'via', '@', 'roznroll'], tags=[108]),
#  TaggedDocument(words=['@', 'allaislouise', '@', 'maxildan', 'aucune', 'considération', 'signalé', 'reporté', 'ce', 'genre', 'de', 'propos', 'n', 'rien', 'de', 'drôle', 'ne', 'doit', 'pas', 'être', 'tenu', 'surtout', 'quand', 'public', 'est', 'jeune', 'influençable', 'balancetonporc'], tags=[109]),
#  TaggedDocument(words=['pédocriminalité', '20180122', 'gt', 'orne', '|', 'cour', 'd', '’', 'assises', 'viol', 'tentative', 'de', 'viol', '8', 'ans', 'de', 'pris'], tags=[110]),
#  TaggedDocument(words=['sur', '@', 'france5tv', 'ce', 'soir', 'il', 'y', 'avait', '@', 'annefloremarxer', 'pour', 'témoignage', 'sur', 'sexisme', 'dans', 'sport', 'clhebdo'], tags=[111]),
#  TaggedDocument(words=['mate', '2ème', 'épisode', 'bayezer', 'de', '@', 'jeanpascalzadi', 'griezmann', 'manix', 'hampm', 'retour', 'djihadistes', 'catherine', 'deneuve'], tags=[112]),
#  TaggedDocument(words=['ne', 'comprend', 'pas', 'pourquoi', 'on', 'fête', 'journée', 'de', 'femme', 'tous', 'ans', 'jamais', '364', 'journées', 'de', 'lhomme', 'journéedelafemme', 'ironie'], tags=[113]),
#  TaggedDocument(words=['quon', 'ne', 'vienne', 'pas', 'me', 'dire', 'jai', 'lesprit', 'mal', 'placé', 'hein', 'ça', 'voit', 'comme', 'bite', 'au', 'milieu', 'de', 'figure', 'ensemblecontrelesexisme'], tags=[114]),
#  TaggedDocument(words=['catherine', 'deneuve', 'présidente', 'du', 'jury', 'remet', 'grands', 'prix', 'du', 'festival', 'premiersplans', 'angers'], tags=[115]),
#  TaggedDocument(words=['dans', 'monde', 'idéal', 'il', 'faudrait', 'victimes', 'de', 'harcelementscolaire', 'deviennent', 'drh', 'quelles', 'transmettent', 'liste', 'noms', 'de', 'harceleurs', 'type', 'balancetonporc', 'il', 'y', 'aurait', 'ainsi', 'hausse', 'du', 'chômage', 'de', 'très', 'longue', 'durée', 'mais', 'davantage', 'de', 'justice', 'sur', 'terre', '😁ironie'], tags=[116]),
#  TaggedDocument(words=['i24news', '@', 'i24newsfr', 'toujours', 'fidèle', 'notre', 'mouvement', 'balancetonporc', 'metoo', 'prix', 'collectif', 'thanks', 'team', '@', 'benaym', '@', 'time', 'timepersonoftheyear', '@', 'thatdanstewart', '@', 'katesamuelson', '@', 'efelsenthal'], tags=[117]),
#  TaggedDocument(words=['libérer', 'parole', 'femmes', '«', 'dire', 'pour', 'ça', 'change', '»', 'c', '’', 'est', 'thème', 'du', 'colloque', 'de', 'délégation', 'aux', 'droits', 'femmes', 'de', 'l', '’', '@', 'assembleenat', 'l', '’', 'occasion', 'du', '8mars', 'du', 'phénomène', 'metoo', 'balancetonporc'], tags=[118]),
#  TaggedDocument(words=['chien', 's', '’', 'est', 'masturbé', 'sur', 'jambe', 'balancetonporc', 'ok', 'y', 'vrai', 'problème', 'pour', 'autant', 'ne', 'tombons', 'pas', 'dans', 'extrêmes', 'l', '’', 'absurde'], tags=[119]),
#  TaggedDocument(words=['il', 'faut', 'vraiment', 'être', 'affamé', 'sexuel', 'pr', 'sexualiser', 'accessoires', 'aussi', 'minimes', 'sur', 'corps', 'dune', 'femme', 'bientôt', 'rire', 'fera', 'pute'], tags=[120]),
#  TaggedDocument(words=['très', 'bonne', 'initiative', 'de', 'ratp', 'pour', 'prévenir', 'du', 'harcèlement', 'dans', 'transports', 'signalezvous', 'si', 'vous', 'êtes', 'victimes', 'sur', 'bornes', 'de', 'contact', 'au', '3117', 'ou', 'par', 'sms', 'au', '31177', 'balancetonporc', 'metoo'], tags=[121]),
#  TaggedDocument(words=['brexit', 'theresa', 'may', 's', '’', 'embourbe', 'douane'], tags=[122]),
#  TaggedDocument(words=['problème', 'de', 'balancetonporc', 'prend', 'source', 'chez', 'femme', 'car', 'hommes', 'coupables', 'de', 'mauvais', 'comportement', 'envers', 'elles', 'souvent', 'petits', 'garçons', 'maltraités', 'humiliés', 'dans', 'leur', 'enfance', 'par', 'leur', 'mère', 'dautres', 'femmes', 'de', 'leur', 'entourage', 'où', 'lécole', 'psy'], tags=[123]),
#  TaggedDocument(words=['vous', 'présente', 'porcinet', 'nouveau', 'compagnon', 'pour', 'cours', 'balancetonporc'], tags=[124]),
#  TaggedDocument(words=['ça', 'pourrait', 'expliquer', 'pourquoi', 'catherine', 'deneuve', 's', '’', 'est', 'amendée', 'aujourd', '’', 'hui…', 'moiaussi', 'etmaintenant'], tags=[125]),
#  TaggedDocument(words=['02', 'nique', 'ce', 'putain', 'de', 'pays', '04', '02', 'nique', 'dames', 'vertes', '04', '02', 'nique', 'catherine', 'deneuve', '04'], tags=[126]),
#  TaggedDocument(words=['gérald', 'darmanin', 'est', 'concerné', 'par', 'accusations', 'de', 'viol', '▪️wauquiez', 'lr', 'demande', 'de', 'démission', '▪️la', 'majorité', 'larem', 'ovation', 'applaudissements', '▪️marine', 'pen', 'fn', 'ni', 'demande', 'de', 'démission', 'ni', 'ovation', 'buzz', 'indécence', 'de', 'lrlrem', 'hauteur', 'de', 'vue', 'de', '@', 'mlpofficiel'], tags=[127]),
#  TaggedDocument(words=['eh', 'boy…', 'par', 'où', 'commencer', 'hommes', 'méfierontils', 'femmes', 'polqc', 'moiaussi'], tags=[128]),
#  TaggedDocument(words=['travailleuses', 'du', 'syndicat', 'unifor', 'québec', 'lors', 'de', 'formation', 'femmes', 'santé', 'sécurité', 'au', 'travail', 'manifestent', 'leur', 'appui', 'aux', 'femmes', 'du', 'mouvement', 'moiaussi', 'metoo', 'portant', 'fièrement', 'coeur', 'jaune', 'du', 'mouvement', 'etmaintenant'], tags=[129]),
#  TaggedDocument(words=['n', '’', 'oublions', 'pas', 'johnny', 'balancetonporc', 'lui', 'aussi'], tags=[130]),
#  TaggedDocument(words=['vous', 'croyez', '@', 'marleneschiappa', 'rend', 'hommage', 'au', 'même', 'type', 'celui', 'qui', 'accusé', 'de', 'viol', 'par', 'ex', 'femme', 'il', 'y', '2', 'ans', 'balancetonporc', 'limites'], tags=[131]),
#  TaggedDocument(words=['@', 'interelles', 'continue', 'engagement', 'pour', 'lutter', 'contre', 'sexisme', 'participant', 'au', 'collectif', 'ensemblecontrelesexisme', 'signature', 'de', 'charte', 'avec', '22', 'associations', 'engagées', 'pour', 'l', 'égalité', 'fh'], tags=[132]),
#  TaggedDocument(words=['etmaintenant', 'lami', 'lecteur', 'lui', 'ai', 'proposé', 'de', 'lire', 'ce', 'texte', 'moiaussi'], tags=[133]),
#  TaggedDocument(words=['grand', 'respect', 'pour', 'annefloremarxer', 'nous', 'sommes', 'contre', 'sexisme', 'inégalité', 'inequality', 'dans', 'sport', 'anneflore', 'marxer', '«', 'sommesnous', 'toutes', 'réduites', 'paire', 'de', 'seins', '»', 'via', '@', 'lequipe'], tags=[134]),
#  TaggedDocument(words=['pour', 'jeunes', 'qui', 'découvrent', 'série', 'friends', 'est', 'sexiste', 'homophobe', 'grossophobe', 'via', '@', 'slatefr'], tags=[135]),
#  TaggedDocument(words=['dans', 'l', '@', 'armeedelair', 'pas', 'dinégalités', 'de', 'salaires', 'entre', 'hommes', 'femmes', '💪🏼👮🏼\u200d♀️👮🏼\u200d♂️+', '50', 'métiers', 'ouverts', 'tous', '♂️♀️', 'ensemblecontrelesexisme'], tags=[136]),
#  TaggedDocument(words=['catperson', 'cette', 'nouvelle', 'littéraire', 'virale', 'moiaussi'], tags=[137]),
#  TaggedDocument(words=['valérie', 'pécresse', 'rien', 'de', 'tel', 'qu1', 'femme', 'pr', 'faire', 'ménage'], tags=[138]),
#  TaggedDocument(words=['suis', 'pour', 'vous', 'donner', 'permission', 'dêtre', 'colère', 'femmes', 'qui', 'ont', 'brisé', 'lomerta', 'sur', 'violences', 'sexuelles', 'nommées', 'personnes', 'de', 'l', '’', 'année', 'par', '@', 'time', 'mouvement', 'est', 'lancé', 'crois', 'quil', 'ne', 's', '’', 'arrêtera', 'plus', 'metoo', 'balancetonporc'], tags=[139]),
#  TaggedDocument(words=['racisme', 'xénophobie', 'stéréotype', 'idéologie', 'apologie', 'antisémitisme', '73', 'ans', 'après', 'shoah', 'ces', 'mêmes', 'idées', 'qui', 'ont', 'tués', '6', 'millions', 'de', 'juifs', 'continuent', 'dêtre', 'exprimées', 'librement', 'sur', 'réseaux', 'sociaux', 'balancetonporc', 'cc', '@', 'jerusaleem', 'weremember', 'you', 'merci', '@', 'frisson2com'], tags=[140]),
#  TaggedDocument(words=['catherine', 'deneuve', 'excuses', 'aux', 'victimes', 'qui', 'ont', 'pu', 'sentir', 'agressées', 'qua', '@', 'youtube'], tags=[141]),
#  TaggedDocument(words=['journéemondialeducompliment', 'de', 'jour', 'comme', 'de', 'nuit', 'par', 'tous', 'temps', 'ils', 'sont', 'mobilisés', 'pour', 'veiller', 'sur', 'notre', 'sécurité', '👏💪', 'bravo', 'merci', 'aux', 'policiers', 'gendarmes', 'sapeurspompiers', 'pour', 'leur', 'engagement'], tags=[142]),
#  TaggedDocument(words=['berlin', 'angela', 'merkel', 'prépare', 'emmanuel', 'macron', 'aux', 'compromis'], tags=[143]),
#  TaggedDocument(words=['fait', 'lextrême', 'droite', 'décidé', 'de', 'prouver', 'largement', 'aussi', 'conne', 'lextrême', 'gauche', 'qui', 'trustait', 'gros', 'titre', 'depuis', 'plusieurs', 'mois', 'cest', 'ça', 'cet', 'concours'], tags=[144]),
#  TaggedDocument(words=['«', 'tout', 'ça', 'avait', 'lieu', 'avant', 'de', 'manière', 'plus', 'privée', 'moiaussi', 'l', '’', 'a', 'fait', 'apparaître', 'sur', 'place', 'publique', 'maintenant', 'trois', 'mois', 'plus', 'tard', 'estce', 'qu', '’', 'on', 'est', 'soudainement', 'passé', 'de', 'l', '’', 'autre', 'côté', 'estce', 'système', 'miraculeusement', 'changé', '»'], tags=[145]),
#  TaggedDocument(words=['enjeux', 'perspectives', 'pour', 'suite', 'structurer', 'prises', 'de', 'parole', 'lengagement', 'contre', 'sexisme', 'qui', 'pour', 'femmes', 'journalistes', 'cantonne', 'dans', 'milieu', 'professionnel', 'mediacastres', 'journalisme', 'compublique', 'compol'], tags=[146]),
#  TaggedDocument(words=['coprésidentes', '@', 'annieguilberteau', '@', 'catherineladousse', 'du', 'collectif', 'ensemblecontrelesexisme', 'introduisent', 'journée', 'au', 'programme', 'identifier', 'manifestations', 'du', 'sexisme', 'préconiser', 'actions', 'fédératrices', 'pr', 'lutter', 'contre', 'ce', 'fléau', '25janvier', 'tftc', 'nomorecliches'], tags=[147]),
#  TaggedDocument(words=['2501', '22', 'organisations', 'réseaux', 'retrouvent', 'demain', 'pour', 'journée', 'ensemblecontrelesexisme', 'avec', '@', 'marleneschiappa', '@', 'laurossignol', '@', 'cometentreprise', 'chez', '@', 'telecomptech', 'travail', 'sante', 'sport', 'culture', '🛑sexisme'], tags=[148]),
#  TaggedDocument(words=['scandale', 'windrush', 'où', 'lon', 'apprend', 'encore', 'fois', 'droite', 'dure', 'toujours', 'problèmes', 'avec', 'immigrés', 'theresa', 'may', 'est', 'directement', 'impliquée'], tags=[149]),
#  TaggedDocument(words=['il', 'voulait', 'juste', 'limportuner', 'hein', 'catherinedeneuve'], tags=[150]),
#  TaggedDocument(words=['ce', 'soir', 'avec', 'mouvement', '@', 'lsansculottes', 'retrouvez', 'léquipe', 'du', 'pôle', 'féminisme', 'de', 'lassociation', 'cactus', 'pour', 'débattre', 'autour', 'de', 'balancetonporc', '@', 'sciencespotlse', 'plus', 'dinformations'], tags=[151]),
#  TaggedDocument(words=['il', 'y', 'cinq', 'mois', 'hashtag', 'balancetonporc', 'apparaissait', 'sur', 'twitter', 'l', '’', 'initiative', 'de', 'journaliste', 'sandra', 'muller', 'elle', 'sera', 'suivie', 'par', '216', '759', 'autres', 'anonymes', 'ou', 'non…', 'franceinfo', 'recueilli', 'témoignages', 'de', 'quelques', 'unes', 'd', '’', 'entre', 'elles', '@', 'lettreaudio'], tags=[152]),
#  TaggedDocument(words=['il', 'y', 'quand', 'même', 'beaucoup', 'dhommes', 'qui', 'comprennent', 'mvt', 'moiaussi', '«', 'qui', 'est', 'tout', 'sauf', 'chasse', 'l', '’', 'homme', 'mais', 'plutôt', 'mouvement', 'de', 'solidarité', 'de', 'libération', 'de', 'parole', '»'], tags=[153]),
#  TaggedDocument(words=['angela', 'merkel', 'lâche', 'emmanuel', 'macron', 'sur', 'projet', 'de', 'budget', 'de', 'zone', 'euro'], tags=[154]),
#  TaggedDocument(words=['@', 'renaudcamus', 'karl', 'lagerfeld', 'dit', 'même', 'chose', 'au', 'sujet', 'méfaits', 'dangela', 'merkel'], tags=[155]),
#  TaggedDocument(words=['@', 'ruquierofficiel', 'avez', 'vous', 'prévu', 'd', '’', 'inviter', 'chilla', 'cette', 'râpeuse', 'féministe', 'qui', 'notamment', 'fait', 'chanson', 'très', 'pertinente', 'sur', 'balancetonporc', 'via', '@', 'youtube'], tags=[156]),
#  TaggedDocument(words=['merci', 'catherine', 'deneuve'], tags=[157]),
#  TaggedDocument(words=['itw', 'de', 'chimamanda', 'ngozi', 'adichie', 'icône', 'féministe', 'ambassadrice', 'de', 'nuit', 'idées', '2018', 'via', '@', 'lexpress'], tags=[158]),
#  TaggedDocument(words=['agressionsexuelle', 'aux', 'îlesdelamadeleine', 'plus', 'de', 'femmes', 'ont', 'dénoncé', 'agressions', 'dont', 'elles', 'ont', 'été', 'victimes', 'metoo', 'moiaussi', '@', 'rqcalacs'], tags=[159]),
#  TaggedDocument(words=['vraigrey', 'il', 'pourrait', 'être', 'dénoncé', 'par', 'balancetonporc', '50nuancesdegrey'], tags=[160]),
#  TaggedDocument(words=['mecs', 'qui', 'pensent', 'qu1', 'meuf', 'qui', 'couche', 'bcp', 'est', 'salope', 'chatte', 'détruite', 'vs', 'êtes', 'nés', 'sage', 'femme', 'vs', 'rafalé', 'tronche', 'ou', 'bi1'], tags=[161]),
#  TaggedDocument(words=['après', 'titre', 'coup', 'de', 'poing', 'de', '@', 'chillaofficiel', 'balancetonporc', 'freestyle', 'poignant', 'metoo', 'de', '@', 'vinswaza', 'enfonce', 'clou', '👏🔥'], tags=[162]),
#  TaggedDocument(words=['qd', 'adhérents', 'lr', 'du', '92', 'affichent', 'arguments', 'aussi', 'odieux', 'ceux', 'de', 'certains', 'essentialistes', 'du', 'pir', 'soutien', 'd', '’', 'un', 'coopté', 'rueillois', 'raciste', 'sexiste', 'censure', 'd', '’', 'administrés', '@', 'patrickollier', '@', 'villederueil', '@', 'vincentpoizat', '@', 'leparisien92', '@', 'malikaakli', '@', 'malliotmarie'], tags=[163]),
#  TaggedDocument(words=['oui', 'mais', 'dans', 'mouvement', 'moiaussi', 'médias', 'sont', 'mis', 'inclure', 'gestes', 'qui', 'avis', 'relevaient', 'parfois', 'plus', 'de', 'séduction', 'de', 'l', '’', 'agression', 'ex', 'regard', 'insistant'], tags=[164]),
#  TaggedDocument(words=['débat', 'débat', 'soit', 'c', '’', 'est', 'oui', 'soit', 'c', '’', 'est', 'non', 'si', 'c', '’', 'est', 'oui', 'faut', 'encore', 'savoir', 'donner', 'pas', 'faire', 'recevoir', 'sinon', 'moi', 'reprends', 'consentement', 'metoo', 'mytho', 'balancetonporc'], tags=[165]),
#  TaggedDocument(words=['blagues', 'sexistes', 'ça', 'tue', '@', 'annecmailfert', 'ensemblecontrelesexisme'], tags=[166]),
#  TaggedDocument(words=['@', 'lemondefr', 'si', 'vous', 'ressembliez', 'catherine', 'deneuve', 'mais', 'vous', 'n', '’', 'avez', 'rien', 'craindre', 'hommes', 'pauvre'], tags=[167]),
#  TaggedDocument(words=['ahah', 'elle', 'me', 'fait', 'trop', 'rire', 'cette', 'fille', 'ironie'], tags=[168]),
#  TaggedDocument(words=['derrière', 'remarque', 'de', 'cet', 'homme', 'scepticisme', 'sexisme'], tags=[169]),
#  TaggedDocument(words=['ce', 'headshot', 'de', 'valérie', 'pécresse', 'contre', 'laurent', 'wauquiez', 'ce', 'matin', 'on', 'va', 'pas', 'sen', 'remettre', '😂😂😂'], tags=[170]),
#  TaggedDocument(words=['100', 'femmes', 'dénoncent', 'mouvement', 'moiaussi', 'france', 'mal', 'de', 'cœur', 'moiaussi'], tags=[171]),
#  TaggedDocument(words=['suis', 'femme', 'matérialiste', 'superficielle', 'qui', 'ne', 'juge', 'quau', 'physique', 'gens', 'beau', 'goss', 'dans', 'team', 'ironie'], tags=[172]),
#  TaggedDocument(words=['@', 'bassinrebel', '@', 'abrutib', 'il', 'nous', 'tient', 'avec', 'migrantsles', '6', 'milliards', 'promis', 'par', 'merkel', '+', 'passeports', 'facilités', 'ne', 'lui', 'suffisent', 'pas', 'évidemment', 'merci', 'angela'], tags=[173]),
#  TaggedDocument(words=['jeremstargate', 'continue', 'plainte', 'pour', '«', 'viol', 'aggravé', 'sur', 'mineur', '»', 'vient', 'dêtre', 'déposée', 'contre', 'pascal', 'cardonna', 'alias', 'babybel'], tags=[174]),
#  TaggedDocument(words=['macron', 'semble', 'fasciné', 'par', '@', 'realdonaldtrump', 'alors', 'theresamay', 'angelamerkel', 'pourtant', 'plus', 'proches', 'alliées', 'usa', 'gardent', 'leurs', 'distances'], tags=[175]),
#  TaggedDocument(words=['@', 'antipodes69', '@', 'briceperrin', '@', 'velojedi', 'dans', 'lidéal', 'oui', 'sauf', 'sur', 'nos', '2', 'derniers', 'déménagements', 'on', 'na', 'pas', 'pu', 'faire', 'de', 'tri', 'ou', 'tout', 'cas', 'pas', 'autant', 'quon', 'laurait', 'voulu', 'femme', 'enceinte', 'enfants', 'gérer'], tags=[176]),
#  TaggedDocument(words=['première', 'ministre', 'britannique', 'theresa', 'may', 'nommé', 'ce', 'matin', 'sajid', 'javid', 'au', 'poste', 'de', 'ministre', 'de', 'lintérieur', 'remplacement', 'damber', 'rudd', 'qui', 'démissionné', 'hier', 'après', 'scandale', 'sur', 'limmigration'], tags=[177]),
#  TaggedDocument(words=['véronique', 'cloutier', 'explique', 'pourquoi', 'elle', 'ne', 'sétait', 'pas', 'prononcée', 'sur', 'moiaussi'], tags=[178]),
#  TaggedDocument(words=['«', 'diversité', 'acteurs', 'est', 'réunie', 'lutte', 'contre', 'sexisme', 'est', 'lutte', 'transversale', '»', 'intervention', 'de', '@', 'marleneschiappa', 'journée', 'ensemblecontrelesexisme'], tags=[179]),
#  TaggedDocument(words=['collectif', 'ensemble', 'contre', 'sexisme', 'organise', '1ère', 'journée', 'nationale', 'contre', 'sexisme', 'avec', 'séquence', 'dédiée', 'l', '’', 'entreprise', 'cet', 'événement', 'gratuit', 'tiendra', 'lécole', 'telecomparistech', 'paris', '13', 'de', '8h30', '18h', '25', 'janvier', 'cc', '@', 'talentuelles'], tags=[180]),
#  TaggedDocument(words=['theresa', 'may', 'visite', 'paris', 'ce', 'mardi', 'comme', 'margaret', 'thatcher', 'juste', 'avant', 'chute'], tags=[181]),
#  TaggedDocument(words=['marc', 'gaboury', 'de', 'boutique', 'de', 'noël', 'de', 'ville', 'de', 'québec', 'yqb', 'québeccity', 'balancetonporc'], tags=[182]),
#  TaggedDocument(words=['collègue', 'de', 'travail', 'est', 'enceinte', 'my', 'god👶🏼😻🎊'], tags=[183]),
#  TaggedDocument(words=['@', 'clairemrb', 'disons', 'sac', 'dune', 'femme', 'correspond', 'au', 'sens', 'accru', 'de', 'lorganisation', 'possède', 'ironie'], tags=[184]),
#  TaggedDocument(words=['non', 'il', 'n', '’', 'y', 'rien', 'd', '’', 'humoristique', 'dans', 'fait', 'd', '’', 'embrasser', 'seins', 'd', '’', 'une', 'femme', 'contre', 'gré', 'tpmp', 'droitdesfemmes', 'balancetonporc', 'c8', 'ce', 'c8', 'mise', 'demeure', 'pour', 'baiser', 'de', 'jeanmichel', 'maire', 'sur', 'seins', 'dune', 'invitée', 'de', 'tpmp'], tags=[185]),
#  TaggedDocument(words=['@', 'ouhloulouh', 'parce', '1', 'mel', 'veut', 'faire', 'passer', 'pour', 'fille', 'bien', 'alors', 'benji', 'non', '2', 'elle', 'méprise', 'gens', 'alors', 'benji', 'non', 'tout', 'simplement'], tags=[186]),
#  TaggedDocument(words=['@', 'leonera19', 'surtout', 'pour', 'tir', 'de', 'femme', 'enceinte'], tags=[187]),
#  TaggedDocument(words=['us', '2eme', 'anniversaire', 'de', 'marche', 'femmes', 'pour', 'faire', 'reculer', 'sexisme', 'via', '@', 'lemondefr'], tags=[188]),
#  TaggedDocument(words=['ségolène', 'royal', 'obtient', 'finalement', 'poste', 'de', 'reine', 'neiges'], tags=[189]),
#  TaggedDocument(words=['emmanuel', 'macron', 'theresa', 'may', 'veulent', 'renforcer', 'l', '’', 'interdiction', 'armes', 'chimiques'], tags=[190]),
#  TaggedDocument(words=['députées', 'fédérales', 'incertaines', 'de', 'lavenir', 'du', 'mouvement', 'moiaussi', 'multiplication', 'du', 'motclic', 'moiaussi', 'metoo', 'sur', 'réseaux', 'sociaux', 'encouragé', 'plusieurs', 'personnes', 'travers', 'monde', 'partager', 'leur', 'histoire', 'dagression', 'de', 'harcèlement'], tags=[191]),
#  TaggedDocument(words=['angela', 'merkel', 'pas', 'de', 'participation', 'de', 'l', '’', 'allemagne', 'frappes', 'syrie'], tags=[192]),
#  TaggedDocument(words=['il', 'consiste', 'quoi', 'cet', 'hashtag', 'balancetonporc'], tags=[193]),
#  TaggedDocument(words=['bravo', '@', 'theresamay', 'enfin', 'femme', 'qui', 'c'], tags=[194]),
#  TaggedDocument(words=['c', 'est', 'curieux', 'cette', 'mme', 'borne', 'qui', 'passe', 'temps', 'mettre', 'cause', 'l', 'ancien', 'gouvernement', 'ressemble', 'étrangement', 'l', 'ancienne', 'directrice', 'de', 'cabinet', 'de', 'ségolène', 'royal', 'qui', 'avait', 'tutelle', 'sur', 'transports'], tags=[195]),
#  TaggedDocument(words=['@', 'muboo', 'jen', 'peux', 'plus', 'du', 'féminisme', 'via', '@', 'afterhappyhour', 'ahhhiiiii', 'mécréante', 'ironie'], tags=[196]),
#  TaggedDocument(words=['@', 'leparisien', 'après', 'comportement', 'sexiste'], tags=[197]),
#  TaggedDocument(words=['twitter', 'reste', 'petit', 'milieu', '37', 'français', 'ne', 'savent', 'pas', 'ce', 'quest', 'campagne', 'balancetonporc'], tags=[198]),
#  TaggedDocument(words=['imagine', 'elle', 'revient', 'octobre', '2018debut', '2019', 'avec', 'l', '’', 'edf', 'as', 'quoi', '68', 'mois', 'pour', 'te', 'préparer', 'avec', 'bleues', 'donc', 'ça', 'fait', '56', 'matchs', 'top', 'imagine', 'petite', 'blessure', 'lors', 'de', 'saison', 'elle', 'loupe', 'on', 'peut', 'pas', 'travailler', 'automatismes'], tags=[199]),
#  TaggedDocument(words=['ce', 'qui', 'est', 'bien', 'avec', 'balancetonporc', 'cest', 'présemption', 'dinnocence', 'disparait', 'totalement', 'ironie'], tags=[200]),
#  TaggedDocument(words=['créatrice', 'de', 'balancetonporc', 'poursuivie', 'diffamation', 'via', '@', 'franceinfo', 'balancetonporc', 'diffamation'], tags=[201]),
#  TaggedDocument(words=['on', 'vient', 'de', 'me', 'claquer', 'cul', 'putain', 'de', 'beauf', 'blanc', 'cisgenre', 'salade', 'tomate', 'oignon', 'intérieur', 'cuir', 'balancetonporc'], tags=[202]),
#  TaggedDocument(words=['emmanuel', 'macron', 'theresa', 'may', 'veulent', 'renforcer', 'l', '’', 'interdiction', 'armes', 'chimiques'], tags=[203]),
#  TaggedDocument(words=['rt', '@', 'jdequebec', 'femme', 'enceinte', 'cherche', 'médecin', 'québec', 'santé', 'suivi', 'grossesse'], tags=[204]),
#  TaggedDocument(words=['l', '@', 'udaannonceurs', 'craint', 'législateur', 'mette', 'nez', 'dans', 'secteur', 'publicitaire', 'alors', 'ils', 'sengagent', 'contre', 'clichés', 'créant', 'ainsi', '3784e', 'charte', 'de', 'lindustrie', 'contre', 'sexisme', 'qui', 'croit', 'encore', 'lautorégulation'], tags=[205]),
#  TaggedDocument(words=['travail', 'domicile', 'khloé', 'kardashian', 'enceinte', 'découvrez', 'tous', 'derniers', 'détails', 'sur', 'grossesse'], tags=[206]),
#  TaggedDocument(words=['est', 'ce', 'femmes', 'passent', 'leur', 'temps', 'commenter', 'coupe', 'pantalons', 'hommes', 'publics', 'chemises', 'plus', 'ou', 'moins', 'moulantes', 'vestes', 'croisées', 'ou', 'non', 'pourrons', 'nous', 'jour', 'être', 'femme', 'jupe', 'robe', 'mini', 'midi', 'ou', 'longue', 'être', 'écoutée', 'pour', 'ce', 'quon', 'dire'], tags=[207]),
#  TaggedDocument(words=['volleyball', 'magicienne', 'marie', 'tari', 'marie', 'tari', 'après', '195', 'sélections', 'chez', 'bleues', 'belle', 'aventure', 'tête', 'de', 'léquipe', 'de', 'france', 'juniors', 'polynésienne', 'marie', 'tari', 'nen', 'pas', 'fini', 'avec', 'volley', 'rencontre…', 'portrait', 'vosrendezvous'], tags=[208]),
#  TaggedDocument(words=['catherinedeneuve', 'présidente', 'du', 'jury', 'distribuant', 'prix', 'cérémonie', 'de', 'clôture', 'angers', 'premierplans', 'russie'], tags=[209]),
#  TaggedDocument(words=['balancetonporc', 'libération', 'de', 'parole', 'sous', 'caution', 'médiatique'], tags=[210]),
#  TaggedDocument(words=['+1', 'cest', 'valable', 'pour', 'toutes', 'discriminations', 'systémiques', 'sexisme', 'racisme', 'validisme', 'dont', 'psychophobie', 'lgbtphobies', 'dont', 'l', 'homophobie', 'etc', 'si', 'vous', 'nêtes', 'pas', 'ou', 'navez', 'pas', 'été', 'concernées', 'écoutez', 'celleux', 'qui', 'sont', 'ou', 'lont', 'été'], tags=[211]),
# ...
#  TaggedDocument(words=['fautil', 'abolir', 'ce', 'concours', 'ringard', '@', 'lobs', 'pose', 'question', 'parade', 'inutile', 'missfrance2018', 'hasbeen', 'sexiste'], tags=[928]),
#  TaggedDocument(words=['trop', 'cool', 'jaimerai', 'bien', 'gagner', '😀', '@', 'lessmartaddicts💜1', 'enceinte', '🎸bluetooth', 'colorblock😱💚🎶à', 'gagner', '=', 'rêve', 'pour', 'noël', 'car', 'jai', 'cassé', 'mienne', 'hier', 'dans', 'langle', 'dune', 'table', 'de', 'travail🎁tirezmoi', 'svp👍merci😊c', 'follow'], tags=[929]),
#  TaggedDocument(words=['weinsten', 'est', 'juste', 'titre', 'cloué', 'au', 'pilori', 'polanski', 'est', 'célébré', 'hypocrisie', 'française', 'balancetonporc'], tags=[930]),
#  TaggedDocument(words=['vp2', '|', 'apres', 'metoo', 'balancetonporc', 'où', 'eston', 'gtegalitefh', 'journeedesdroitsdesfemmes', '8mars', 'lt3'], tags=[931]),
#  TaggedDocument(words=['achat', 'du', 'jour', 'très', 'bon', 'livre', 'payetashnek', 'sinon', 'check'], tags=[932]),
#  TaggedDocument(words=['«', 'sommesnous', 'toutes', 'réduites', 'paire', 'de', 'seins', '»', 'sexisme', 'sport', 'coup', 'de', 'gueule', 'de', 'championne', 'de', 'snowboard', '@', 'annefloremarxer', 'dans', 'clhebdo'], tags=[933]),
#  TaggedDocument(words=['royaumeuni', 'vous', 'ai', 'mis', 'dans', 'ce', 'pétrin', 'vais', 'vous', 'sortir', 'dit', 'theresa', 'may', 'aux', 'conservateurs', 'afp'], tags=[934]),
#  TaggedDocument(words=['24', 'janvier', 'entre', 'galanterie', 'sexisme', 'comment', 'donc', 'comporter', 'entre', 'hommes', 'femmes', 'on', 'débat', '9h', 'sur', '@', 'radionotredame', 'avec', '@', 'eugeniebastie', 'claude', 'habib', 'guilhem', 'de', '@', 'gevigney', 'droits', 'femmes', 'egalitefh'], tags=[935]),
#  TaggedDocument(words=['@', 'frhaz', '@', 'partisocialiste', '@', 'rachidtemal', 'ne', 'suis', 'pas', 'daccord', 'devrais', 'etre', 'radié', 'tv', 'radio', '@', 'lcp', '@', 'csa', 'balancetonporc'], tags=[936]),
#  TaggedDocument(words=['dessin', 'de', 'jerc', 'du', 'vendredi', '15', 'décembre', '2017', 'caricature', 'robert', 'menard', 'balance', 'porc'], tags=[937]),
#  TaggedDocument(words=['linkedintopvoices', 'merci', '@', 'interelles', '@', 'lenovofr', 'toutes', 'engagées', 'pour', 'legalité', 'fh', 'mixité', 'ensemblecontrelesexisme', '@', 'laurossignol', '@', 'marleneschiappa', '@', 'thaimasamman', '@', 'brigittegresy', '@', 'claudineschmuck', '@', 'lbeldowski', '@', 'emmalarroque', '@', 'sandchauvin', '@', 'dom221148'], tags=[938]),
#  TaggedDocument(words=['blog', 'participatif', 'pour', 'dénoncer', 'exposer', 'sur', 'toile', 'payetafac', 'payetashnek', 'tumblr'], tags=[939]),
#  TaggedDocument(words=['ils', 'veulent', 'femme', 'avec', 'du', 'caractère', 'mais', 'pas', 'sauvage', 'de', 'mieux', 'mieux', 'hommes', 'st', 'pas', 'compliqué', 'du', 'touuut', 'ironie'], tags=[940]),
#  TaggedDocument(words=['artistes', '@', 'femmessolidaire', 'vous', 'disent', 'merci', '@', 'laurythilleman', 'bigup', 'bientôt', 'on', 'continue', 'ensemblecontrelesexisme', 'unefoispourtoutes'], tags=[941]),
#  TaggedDocument(words=['@', 'kindaka', 'non', 'bien', 'quils', 'soient', 'sympa', 'jachète', 'produits', 'avec', 'argent', 'de', 'travail', 'celle', 'de', 'youtube', 'lenceinte', 'est', 'présentée', 'partenariat', 'donc', 'lai', 'eu', 'gratuitement'], tags=[942]),
#  TaggedDocument(words=['@', 'annedesevrant', 'cinglée', 'hystérique', 'voir', 'bannière', 'bloquée', 'par', 'bcp', 'dont', 'moi', 'prétend', 'sarkoziste', 'mais', 'défendu', 'macron', 'dès', 'première', 'heure', 'ce', 'demander', 'si', 'ce', 'n', '’', 'ait', 'pas', 'taupe'], tags=[943]),
#  TaggedDocument(words=['dessin', '@', 'courrierpicard', '@', 'unionardennais', 'du', '29032018', 'après', 'segoleneroyal', 'rachidadati', 'dit', 'prête', 'pour', 'mairiedeparis'], tags=[944]),
#  TaggedDocument(words=['@', 'belattaryassine', 'alors', '@', 'stephaneguillon', 'te', 'laisse', 'femme', 'parce', 'linvective', 'ah', 'ben', 'bravo', 'stéphane', 'balancetonporc'], tags=[945]),
#  TaggedDocument(words=['avant', 'de', 'partir', 'de', 'chez', 'ex', 'jai', 'mis', 'coups', 'de', 'parfum', 'peu', 'partout', 'jai', 'laissé', 'deux', 'trois', 'affaires', 'moi', 'psychopathe', 'peut', 'être', 'connasse', 'ça', 'cest', 'sûr', '✊️'], tags=[946]),
#  TaggedDocument(words=['dans', 'lettre', 'au', 'journal', 'monde', 'léa', 'clermont', 'dion', 'répond', 'catherine', 'deneuve', 'tlmep', 'moiaussi', '@', 'laclermont'], tags=[947]),
#  TaggedDocument(words=['mots', 'de', 'lannée', '26', '«', 'moiaussi', 'metoo', '»', 'motclic', 'pour', 'balancer', 'porc', 'goldenglobes'], tags=[948]),
#  TaggedDocument(words=['semaineeuropéeenne', 'd', '@', 'emmannuelmacron', 'mardi', '17', 'avril', 'au', 'parlementeuropéen', 'mercredi', '18', 'épinal', 'où', 'il', 'lancé', 'consultationscitoyennes', 'pour', 'leurope', 'jeudi', '20', 'avril', 'berlin', 'pour', 'rencontre', 'avec', 'angelamerkel', 'dynamisme', '🇫🇷🇪🇺'], tags=[949]),
#  TaggedDocument(words=['ce', 'photographe', 'inverse', 'rôles', 'pour', 'dénoncer', 'publicités', 'sexistes', '🚹🚺', 'on', 'ne', 'peut', 'quadorer', 'sexisme'], tags=[950]),
#  TaggedDocument(words=['mouvements', 'sociaux', 'guyane', 'christiane', 'taubira', 'sest', 'rendue', 'rencontre', 'personnes', 'mobilisées', 'kourou'], tags=[951]),
#  TaggedDocument(words=['@', 'derzorngottes', '@', 'gerardcollomb', '@', 'elisefajgeles', '12', 'cette', 'jeune', 'femmesortie', 'de', 'détention', 'pour', 'trafic', 'de', 'stupéfiantsa', 'été', 'placée', '282', 'centre', 'de', 'rétention', 'administrative', 'avec', 'bébé', 'vue', 'de', 'leur', 'éloignement', 'vers', 'paraguay', 'ils', 'nont', 'jamais', 'séjourné', 'dans', 'bâtiment', 'touché', 'par', 'panne', 'de', 'chauffage', '@', 'lobs', '@', 'widadk'], tags=[952]),
#  TaggedDocument(words=['«', 'nous', 'allons', 'investir', '5', 'milliards', 'dans', 'l', '’', 'agriculture', 'sur', 'quinquennat', '»', 'sia2018', '@', 'lci'], tags=[953]),
#  TaggedDocument(words=['balancetonmecsupercool', 'aujourdhui', 'nai', 'traité', 'aucune', 'femme', 'de', 'salope', 'bon', 'même', 'temps', 'suis', 'pas', 'sorti'], tags=[954]),
#  TaggedDocument(words=['theresamay', 'pm', 'angleterre', 'voilales', 'hommes', 'qui', 'font', 'connet', 'on', 'appelle', 'encore', '1', 'femme', 'laide', '😯😩🏃🏃😂'], tags=[955]),
#  TaggedDocument(words=['bennomdidju', 'égalité', 'harcèlement', 'balancetonporc', 'nom', 'di', 'dju', 'cest', 'vrai', 'tiens'], tags=[956]),
#  TaggedDocument(words=['retour', 'de', 'bâton', 'après', 'balancetonporc', 'colletadindeautribunal', 'via', '@', 'bvoltaire'], tags=[957]),
#  TaggedDocument(words=['@', 'bardamuvoyage', '@', 'pierredelecourt', '@', 'qofficiel', '@', 'ylebolloch', '@', 'theresamay', 'pardon', 'de', 'te', 'contredire', 'mais', 'france', 'toujours', 'été', 'deuxième', 'cest', 'lempire', 'colonial', 'britannique', 'qui', 'est', 'sur', 'première', 'marche', 'du', 'podium'], tags=[958]),
#  TaggedDocument(words=['interview', 'metoo', 'balancetonporc', 'gardecorps', 'premier', 'roman', 'de', 'politologue', 'virginie', 'martin', '|', 'blogazoi'], tags=[959]),
#  TaggedDocument(words=['moi', 'suis', 'femme', 'de', 'devoir', 'quot', 'ségolène', 'royal', 'sur', 'itele'], tags=[960]),
#  TaggedDocument(words=['finir', 'avec', 'clichés', 'sur', 'femmes', 'au', 'volant', 'sexisme', 'égalitéfh', 'automobile'], tags=[961]),
#  TaggedDocument(words=['jose', 'porter', 'bottes', 'talons', 'pajol', 'paris18', 'jai', 'eu', 'droit', '3', 'coquine', 'salope', '3min', 'rien', 'ne', 'vous', 'choque', '@', 'mairie18paris', 'on', 'laisse', 'comme', 'ça', 'tout', 'va', 'bien', 'on', 'ne', 'soccupe', 'tjs', 'pas', 'de', 'place', 'femmes', 'dans', 'quartier', 'balancetonporc', '@', 'marleneschiappa'], tags=[962]),
#  TaggedDocument(words=['femmes', 'journalistes', 'de', '@', 'lobs', 'du', 'parisien', 'plaignent', 'du', 'sexisme', 'de', 'leur', 'rédaction'], tags=[963]),
#  TaggedDocument(words=['analyse', 'moiaussi', 'metoo', 'allégations', 'de', 'nature', 'sexuelle', 'twitter', 'face', 'létat', 'de', 'droit'], tags=[964]),
#  TaggedDocument(words=['elle', 'est', 'mignonne', '@', 'celinecalvez', '@', 'lreman', 'nkm', 'mieux', 'ceci', 'nest', 'pas', 'blague', 'sexiste'], tags=[965]),
#  TaggedDocument(words=['tout', 'soutien', '@', 'auroreberge', 'personne', 'n', '’', 'a', 'droit', 'de', 'commenter', 'tenue', 'd', '’', 'une', 'femme', 'seule', 'chose', 'qu', '’', 'une', 'jupe', 'révèle', 'c', '’', 'est', 'machisme', 'ordinaire'], tags=[966]),
#  TaggedDocument(words=['aurore', 'bergé', 'em', 'n°439618', 'dans', 'classement', 'du', '22022018', '@', 'auroreberge', 'perdu', '308', 'places'], tags=[967]),
#  TaggedDocument(words=['qui', 'peut', 'croire', 'accusations', 'de', 'femme', 'qui', 'est', 'ex', 'call', 'girl', 'contre', 'darmanin', 'sont', 'fondées', 'club', 'libertin', 'puis', 'chambre', 'd', '’', 'hôtel', 'moment', 'elle', 'été', 'surprise'], tags=[968]),
#  TaggedDocument(words=['@', 'willypasche', 'vidéo', 'passe', 'arrière', 'sarah', 'n', 'est', 'pas', 'assez', 'appuyée', 'pis', 'vs', 'allemagne', 'si', 'on', 'lécoute', 'c', 'est', 'faute', 'de', 'méline', 'sarah', 'cest', 'facile', 'ballon', 'est', 'rentré', 'qd', 'gb', 'italienne', 'prend', 'plus', 'envie', 'de', 'senerver', 'dvt', 'ce', 'fait', 'de', 'nos', 'bleues', 'c', 'est', 'triste'], tags=[969]),
#  TaggedDocument(words=['laurence', 'rossignol', 'jugé', 'faits', 'daccusation', 'de', 'viol', 'contre', 'gérald', 'darmanin', 'embarrassants', 'pour', 'gouvernement', 'mais', '@', 'laurossignol', 'na', 'pas', 'été', 'embarrassée', 'de', 'faire', 'au', 'micro', 'de', 'frédéric', 'haziza', 'accusé', 'dagression', 'sexuelle'], tags=[970]),
#  TaggedDocument(words=['1', 'palme', 'de', 'couverture', 'sexiste', 'de', 'semaine', 'revient', 'à', '@', 'voici'], tags=[971]),
#  TaggedDocument(words=['bande', 'd', '’', 'hypocrites', 'christian', 'grey', 'maltraite', 'meuf', 'dégrade', 'statut', 'de', 'femme', 'vous', 'dites', 'c', '’', 'est', 'de', 'l', '’', 'amour', 'c', '’', 'est', 'juste', 'parce', 'qu', '’', 'il', 'est', 'riche', 'si', 'c', '’', 'était', 'pauvre', 'tout', 'monde', 'aurait', 'crié', 'au', 'scandale', '50nuancesdegrey', 'tf1', 'balancetonporc'], tags=[972]),
#  TaggedDocument(words=['@', 'lci', 'payetashnek', 'texto', 'automatique', 'pour', 'éduquer', 'ceux', 'qui', 'vous', 'harcèlent'], tags=[973]),
#  TaggedDocument(words=['importante', 'interview', 'de', '@', 'annefloremarxer', 'qui', 'explique', 'engagement', 'pour', 'reconnaissance', 'filles', 'dans', 'sports', 'actions', 'mais', 'aussi', 'surtout', 'triste', 'réalité', 'toujours', 'actuelle', 'du', 'milieu', 'sexisme', 'liberezsaparole', 'via', '@', 'neufdixieme'], tags=[974]),
#  TaggedDocument(words=['journaliste', 'qui', 'lancé', 'balancetonporc', 'poursuivie', 'justice', 'par', 'personne', 'dénoncée', 'publiquement'], tags=[975]),
#  TaggedDocument(words=['bon', 'papier', 'moiaussi', 'dis', 'etmaintenant', 'via', '@', 'lplapresse'], tags=[976]),
#  TaggedDocument(words=['ledirect', 'gt', 'footballféminin', 'gt', 'cest', 'mitemps', 'du', 'match', 'amical', 'fraita', 'au', 'velodrome', 'bleues', 'neutralisent', 'sur', 'score', 'de', 'partout', 'face', 'aux', 'italiennes', 'malgré', 'large', 'domination', 'suite', 'énorme', 'erreur', 'de', 'sbouhaddi', 'buts', 'cgirelli', '6', 'ahenry', '17'], tags=[977]),
#  TaggedDocument(words=['soutien', 'total', 'collègue', '@', 'auroreberge', 'victime', 'de', 'propos', 'incroyablement', 'intolérablement', 'misogynes'], tags=[978]),
#  TaggedDocument(words=['madame', 'catherinedeneuve', 'annoncée', 'lors', 'du', 'festival', 'premiersplansdangers', 'allait', 'tournée', 'pour', 'huitième', 'fois', 'avec', 'andretechine'], tags=[979]),
#  TaggedDocument(words=['moiaussi', 'dis', 'etmaintenant', 'via', '@', 'lplapresse'], tags=[980]),
#  TaggedDocument(words=['+31', 'de', 'plaintes', 'pour', 'agressions', 'sexuelles', 'viols', 'lors', 'du', 'dernier', 'trimestre', '2017', 'par', 'rapport', 'même', 'période', '2016', 'saluons', 'courage', 'de', 'celles', 'qui', 'ont', 'osé', 'parler', 'faisons', 'sorte', 'cette', 'libération', 'de', 'parole', 'ne', 'soit', 'quun', 'début', 'balancetonporc'], tags=[981]),
#  TaggedDocument(words=['cher', 'ami', 'penelope', 'fillon', 'est', 'plus', 'même', 'd', 'éclairer', 'votre', 'lanterne'], tags=[982]),
#  TaggedDocument(words=['fais', 'pas', 'lamour', 'femme', 'comme', 'homme', 'bible', 'dit', 'qucest', 'abomination', 'alors', 'chaque', 'fois', 'quje', 'tencule', 'jdemande', 'pardon', 'au', 'ciel', 'pour', 'faute', 'd', '’', 'inattention'], tags=[983]),
#  TaggedDocument(words=['fait', 'quil', 'ny', 'ait', 'pas', 'de', 'femmes', 'on', 'parle', 'moment', 'emissiondemachos', 'theisland', 'feministe', 'ironie'], tags=[984]),
#  TaggedDocument(words=['femme', 'habillée', 'dune', 'certaine', 'manière', 'mais', 'vierge', 'est', 'pute', 'gars', 'qui', 'fourre', 'quéquette', 'partout', 'c', 'guerrier', 'who', 'raised', 'yall🤔'], tags=[985]),
#  TaggedDocument(words=['@', 'malborot2', '@', 'perrinest', '1', 'mort', '8', 'blessés', 'dont', '1', 'femme', 'enceinte', 'ki', 'perdu', 'enfant', 'suite', 'o', 'tir', 'lors', 'dune', 'soirée', 'gâteaux', 'pour', 'trouver', 'prénom', 'du', 'futur', 'enfant12'], tags=[986]),
#  TaggedDocument(words=['metoo', 'merci', 'catherine', 'deneuve', 'merci', 'catherine', 'millet', 'de', 'nous', 'rappeler', 'combat', 'est', 'très', 'loin', 'd', '’', 'être', 'gagné…', 'nouveaupost'], tags=[987]),
#  TaggedDocument(words=['si', 'on', 'faisait', 'pareil', 'avec', 'connards', 'qui', 'menacent', 'appellent', 'au', 'viol', 'on', 'vu', 'plein', 'sur', 'tl', 'de', 'celles', 'qui', 'utilisaient', 'balancetonporc', 'il', 'faudrait', 'construire', '15x', 'plus', 'de', 'prisons', 'france'], tags=[988]),
#  TaggedDocument(words=['trump', 'toujours', 'obsédé', 'par', 'obama', 'bonne', 'relation', 'avec', 'angela', 'merkel', 'lui', 'dit', 'conférence', 'de', 'presse', '«', 'prédécesseur', 'n', '’', 'a', 'pas', 'fait', 'du', 'bon', 'travail', 'mais', 'nous', 'allons', 'essayer', 'de', 'vous', 'récupérer', 'nous', 'allons', 'essayer', '»', 'petit', 'sourire', 'amusé', 'de', 'chancelière'], tags=[989]),
#  TaggedDocument(words=['margaret', 'thatcher', 'ou', 'femme', 'plus', 'aimé', 'ironie', 'est', 'morte', 'aujourdhui'], tags=[990]),
#  TaggedDocument(words=['pour', 'ceuxcelles', 'qui', 'ne', 'comprennent', 'pas', 'différence', 'entre', 'agresser', 'séduire', 'court', 'texte', 'encore', 'bien', 'dans', 'l', '’', 'air', 'du', 'temps', 'moiaussi', 'meetoo'], tags=[991]),
#  TaggedDocument(words=['linqualifiable', 'aurore', 'bergé'], tags=[992]),
#  TaggedDocument(words=['célébration', 'de', 'vie', 'de', 'liberté', 'nos', 'héros', 'ce', 'soir', 'aux', 'cesar2018', 'avec', '120battementsparminute', 'aurevoirlahaut', 'ou', 'barbara', 'cinéma', 'français', 'sans', 'cesse', 'créatif', 'vibrant', 'engagé', '👏👏👏'], tags=[993]),
#  TaggedDocument(words=['mettez', 'j', '’', 'aime', 'si', 'vous', 'pensez', 'suis', 'connasse', 'retweetez', 'si', 'vous', 'pensez', 'suis', 'bonnasse', 'j', '’', 'attends', 'vos', 'avis'], tags=[994]),
#  TaggedDocument(words=['@', 'mikofficiel', 'euh', 'perso', 'vivian', 'yeux', 'qui', 'disent', 'bjr', 'ne', 'laisserait', 'aucune', 'fille', 'de', 'marbre', 'ironie', 'marcelbcptroppiquants'], tags=[995]),
#  TaggedDocument(words=['félicitations', '@', 'bnpparibas', '@', 'sogeti', 'davoir', 'pris', 'devants', 'sensibilisé', 'leurs', 'rh', 'managers', 'détection', 'prévention', 'du', 'sexisme', 'du', 'harcèlementsexuel'], tags=[996]),
#  TaggedDocument(words=['moi', 'ne', 'suis', 'plus', 'républicains', 'cause', 'de', 'cette', 'pécresse', 'qui', 'na', 'rien', 'y', 'faire', 'cette', 'tourne', 'jaquette', 'autres', 'qui', 'ont', 'tourné', 'dos', 'fillon', 'sont', 'pas', 'mieux', 'donc', 'préfère', 'être', 'avec', 'femme', 'qui', 'ne', 'change', 'pas', '@', 'mlpofficiel'], tags=[997]),
#  TaggedDocument(words=['femme', 'enceinte', 'grand', 'mère', 'faisait', 'pareil', 'mere', 'suite', 'au', 'tir', 'de', 'payet', 'fraall'], tags=[998]),
#  TaggedDocument(words=['communique', 'de', 'presse', 'est', 'sorti', 'de', 'presse', 'goldenglobes', 'moiaussi'], tags=[999]),
#  ...]

# %% [markdown]
# ###### 5th step : train the model

# %%
model = Doc2Vec(tagged_data, vector_size = 20, window = 2, min_count = 1, epochs = 100)

# %% [markdown]
# ###### 6th step : testing the model

# %%
def predicted_category(sentence):
    sentence = sentence.lower()
    test_doc = word_tokenize(sentence)
    test_doc_vector = model.infer_vector(test_doc)
    similar_sentences = model.docvecs.most_similar(positive = [test_doc_vector]) 
    similar_senetences_categories = [y_tokenized[similar_sentences[i][0]] for i in range(len(similar_sentences))]

    nb_0 = similar_senetences_categories.count(0)
    nb_1 = similar_senetences_categories.count(1)
    
    if(nb_0 <= nb_1):
        return 1
    
    else:
        return 0

    
predictions = []    
for sentence in X_test:
    predictions.append(predicted_category(sentence))
    
print("Accuracy : ", np.mean(predictions == y_test))
metrics.confusion_matrix(y_test, predictions)
# Out:
# <ipython-input-73-469006f638e4>:5: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   similar_sentences = model.docvecs.most_similar(positive = [test_doc_vector])
# Accuracy :  0.691005291005291
# array([[518, 117],
#        [175, 135]], dtype=int64)

# %% [markdown]
# ### Word Embedding using tensorflow keras

# %%
vocab_size = 1000
embedding_dim = 16
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_portion = .8

# %%
data = pd.read_csv("my_csv_clean.csv",sep = ',') #we got that csv after running the Text Preprocessing file
data.columns = ['tweet', 'class']
    

sentences = list(data['tweet'])
labels = [categories[i] for i in data['class']]

print(labels)
# Out:
# ['not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexi ...

# %%
#splitting dataset
train_size = int(len(sentences) * training_portion)
train_sentences = sentences[:train_size] #X_train
train_labels = labels[:train_size] #y_train
validation_sentences = sentences[train_size:] #X_test

validation_labels = labels[train_size:] #y_test
print(train_labels)
# Out:
# ['not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexist', 'not_sexi ...

# %%
#tokenizing sentences
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(train_sentences)

# %%
word_index = tokenizer.word_index
total_words = len(word_index)+1 #1 for oov word
print(total_words)
print(word_index)
# Out:
# 11475
# {'<OOV>': 1, 'de': 2, 'pour': 3, 'balancetonporc': 4, 'du': 5, 'qui': 6, 'pas': 7, 'sur': 8, 'dans': 9, 'est': 10, 'sexisme': 11, 'moiaussi': 12, 'femme': 13, 'au': 14, 'ce': 15, 'avec': 16, 'ne': 17, 'par': 18, 'on': 19, 'femmes': 20, 'plus': 21, 'cest': 22, 'il': 23, 'contre': 24, 'vous': 25, 'metoo': 26, 'merkel': 27, 'ça': 28, 'mais': 29, 'fait': 30, 'via': 31, 'comme': 32, '»': 33, 'nous': 34, 'angela': 35, '«': 36, 'aux': 37, 'sont': 38, 'cette': 39, 'ou': 40, 'si': 41, 'tout': 42, 'sexiste': 43, 'elle': 44, 'monde': 45, 'ensemblecontrelesexisme': 46, 'ont': 47, 'après': 48, 'bleues': 49, 'mouvement': 50, 'ironie': 51, 'viol': 52, 'faire': 53, 'bien': 54, 'etmaintenant': 55, 'leur': 56, 'quand': 57, 'y': 58, 'france': 59, 'même': 60, 'aussi': 61, 'royal': 62, 'journée': 63, 'c’est': 64, 'harcèlement': 65, 'suis': 66, 'match': 67, 'macron': 68, 'être': 69, 'merci': 70, 'ségolène': 71, 'hommes': 72, 'me': 73, 'été': 74, 'tous': 75, 'travail': 76, 'notre': 77, 'non': 78, 'may': 79, 'très': 80, 'entre': 81, 'marleneschiappa': 82, 'theresa': 83, 'homme': 84, 'politique': 85, 'jai': 86, 'va': 87, 'ans': 88, 'fille': 89, 'collectif': 90, 'parole': 91, 'dit': 92, 'encore': 93, 'féministe': 94, 'alors': 95, 'moi': 96, 'christiane': 97, 'taubira': 98, 'deneuve': 99, 'pourquoi': 100, 'victimes': 101, 'catherine': 102, 'ces': 103, 'dire': 104, 'toujours': 105, 'peut': 106, 'rien': 107, 'violences': 108, 'payetashnek': 109, 'ministre': 110, 'parce': 111, 'avoir': 112, 'nest': 113, 'parler': 114, 'comment': 115, 'temps': 116, 'oui': 117, 'quil': 118, 'voir': 119, 'lui': 120, 'où': 121, 'aujourdhui': 122, 'donc': 123, 'enceinte': 124, 'parle': 125, 'dune': 126, '2017': 127, 'darmanin': 128, 'sans': 129, 'nos': 130, 'ils': 131, 'sexuel': 132, 'votre': 133, '2018': 134, 'dun': 135, '25': 136, 'première': 137, 'bravo': 138, 'faut': 139, 'trop': 140, 'soir': 141, 'sexuelles': 142, 'toutes': 143, 'beaucoup': 144, 'deux': 145, 'bon': 146, 'juste': 147, 'justice': 148, 'c': 149, 'nationale': 150, 'janvier': 151, 'diffamation': 152, 'autres': 153, 'jour': 154, 'l': 155, 'depuis': 156, 'face': 157, 'peu': 158, 'sport': 159, 'racisme': 160, 'féminisme': 161, 'avait': 162, 'courage': 163, 'doit': 164, '1': 165, 'leurs': 166, 'quoi': 167, 'avant': 168, 'propos': 169, 'cela': 170, 'vie': 171, 'moins': 172, 'demain': 173, 'vraiment': 174, 'aurait': 175, 'd': 176, '2': 177, 'millions': 178, 'place': 179, 'emmanuel': 180, 'mieux': 181, 'retour': 182, 'quon': 183, 'bonne': 184, 'puissante': 185, 'sous': 186, 'gens': 187, 'time': 188, 'na': 189, 'salope': 190, 'coup': 191, 'veut': 192, 'selon': 193, 'dont': 194, 'fois': 195, 'maintenant': 196, 'jamais': 197, 'paris': 198, 'amp': 199, 'journaliste': 200, 'droit': 201, 'fillon': 202, 'emmanuelmacron': 203, 'parti': 204, 'trump': 205, 'dis': 206, 'reste': 207, 'grand': 208, 'elles': 209, 'mois': 210, 'déjà': 211, 'porc': 212, 'dêtre': 213, 'français': 214, 'médias': 215, 'chancelière': 216, 'toute': 217, 'lannée': 218, 'j’ai': 219, 'genre': 220, 'vient': 221, 'nouveau': 222, 'theresamay': 223, 'nouvelle': 224, 'société': 225, 'sera': 226, 'auroreberge': 227, 'balance': 228, 'pr': 229, 'lutter': 230, 'presse': 231, 'franceinfo': 232, 'allez': 233, 'lieu': 234, 'celles': 235, 'mettre': 236, 'marche': 237, 'autre': 238, 'libération': 239, 'aujourd’hui': 240, 'bergé': 241, 'tellement': 242, 'sandra': 243, 'campagne': 244, 'sexuelle': 245, 'poursuivie': 246, 'conne': 247, 'fin': 248, 'vidéo': 249, 'hashtag': 250, 'ceux': 251, 'devant': 252, 'twitter': 253, 'gouvernement': 254, 'te': 255, 'mal': 256, 'lire': 257, 'vrai': 258, 'vu': 259, 'premier': 260, 'muller': 261, 'tlmep': 262, 'violence': 263, 'sexe': 264, 'silence': 265, 'droite': 266, 'polqc': 267, 'soit': 268, 'pays': 269, 'certains': 270, 'sujet': 271, 'débat': 272, 'qu’on': 273, 'différence': 274, 'solidarité': 275, 'toi': 276, 'liberté': 277, 'aurore': 278, 'sexistes': 279, 'personnes': 280, 'plainte': 281, 'soutien': 282, 'weinstein': 283, 'chez': 284 ...

# %%
train_sequences = tokenizer.texts_to_sequences(train_sentences)
validation_padded = pad_sequences(validation_sequences, padding=padding_type, maxlen=max_length)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-f709d8df3390> in <module>
#       1 train_sequences = tokenizer.texts_to_sequences(train_sentences)
# ----> 2 validation_padded = pad_sequences(validation_sequences, padding=padding_type, maxlen=max_length)
#       3
#
# NameError: name 'validation_sequences' is not defined

# %%
print(len(train_sentences[1]))
print(len(train_sequences[1]))
print(len(train_padded[1]))
print()
print(train_sentences[1])
print(train_sequences[1])
print(train_padded[1])

# %%
#tokenizing labels
label_tokenizer = Tokenizer()
label_tokenizer.fit_on_texts(labels)

training_label_seq = np.array(label_tokenizer.texts_to_sequences(train_labels))
validation_label_seq = np.array(label_tokenizer.texts_to_sequences(validation_labels))

# %%
print(training_label_seq)
print(training_label_seq.shape)
print(type(training_label_seq[0]))

# %%
#creating model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

# %%
num_epochs = 30
history = model.fit(train_padded, training_label_seq, epochs=num_epochs, 
                    validation_data=(validation_padded, validation_label_seq), 
                    verbose=2)

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

# %%
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
#visualizing embedded words
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
def decode_sentence(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

# %%
e = model.layers[0]
weights = e.get_weights()[0]
print(weights.shape)

# %%
import io
out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('meta.tsv', 'w', encoding='utf-8')
for word_num in range(1, vocab_size):
    word = reverse_word_index[word_num]
    embeddings = weights[word_num]
    out_m.write(word + "\n")
    out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")
out_v.close()
out_m.close()

#use tensorflow embedding projector to visualize results by uploading this vector and metadata

# %% [markdown]
# ### TEST

# %%
vocab_size = 1000
embedding_dim = 16
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_portion = .8

# %%
data = pd.read_csv("my_csv_clean.csv",sep = ',') #we got that csv after running the Text Preprocessing file
data.columns = ['tweet', 'class']
    

X = data['tweet']
y = data['class'] 


categories = ["NotSexist", "Sexist"]

X_train, X_test, y_train , y_test = train_test_split(X , y ,test_size=0.3)

X = list(X)
y = [categories[i] for i in y]
X_train = list(X_train)
X_test = list(X_test)
y_train = [categories[i] for i in y_train]
y_test = [categories[i] for i in y_test]
print(y_train)
# Out:
# ['Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'Sexist', 'Sexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', 'NotSexist', 'Sexist', 'Sexist', 'NotSexist', 'Sexist', 'Sexist', 'Sexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'NotSexist', 'Sexist', 'NotSexist', ' ...

# %%
#tokenizing sentences
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(X_train)

# %%
word_index = tokenizer.word_index
total_words = len(word_index)+1 #1 for oov word
print(total_words)
print(word_index)
# Out:
# 10539
# {'<OOV>': 1, 'de': 2, 'pour': 3, 'balancetonporc': 4, 'du': 5, 'pas': 6, 'qui': 7, 'femme': 8, 'est': 9, 'sur': 10, 'dans': 11, 'sexisme': 12, 'ce': 13, 'au': 14, 'avec': 15, 'ne': 16, 'moiaussi': 17, 'on': 18, 'cest': 19, 'il': 20, 'plus': 21, 'femmes': 22, 'par': 23, 'vous': 24, 'ça': 25, 'mais': 26, 'contre': 27, 'fait': 28, 'metoo': 29, 'comme': 30, 'sexiste': 31, 'elle': 32, 'merkel': 33, '«': 34, 'sont': 35, '»': 36, 'ou': 37, 'si': 38, 'via': 39, 'tout': 40, 'nous': 41, 'aux': 42, 'cette': 43, 'angela': 44, 'faire': 45, 'viol': 46, 'bien': 47, 'après': 48, 'quand': 49, 'aussi': 50, 'c’est': 51, 'me': 52, 'même': 53, 'monde': 54, 'ironie': 55, 'ensemblecontrelesexisme': 56, 'suis': 57, 'hommes': 58, 'ont': 59, 'y': 60, 'harcèlement': 61, 'homme': 62, 'france': 63, 'mouvement': 64, 'leur': 65, 'bleues': 66, 'etmaintenant': 67, 'merci': 68, 'été': 69, 'moi': 70, 'royal': 71, 'enceinte': 72, 'être': 73, 'va': 74, 'non': 75, 'jai': 76, 'dit': 77, 'ans': 78, 'fille': 79, 'pourquoi': 80, 'tous': 81, 'journée': 82, 'travail': 83, 'ségolène': 84, 'encore': 85, 'très': 86, 'match': 87, 'macron': 88, 'salope': 89, 'ces': 90, 'lui': 91, 'alors': 92, 'marleneschiappa': 93, 'peut': 94, 'féministe': 95, 'faut': 96, 'entre': 97, 'donc': 98, 'parce': 99, 'deneuve': 100, 'payetashnek': 101, 'may': 102, 'où': 103, 'darmanin': 104, 'theresa': 105, 'catherine': 106, 'notre': 107, 'rien': 108, 'avoir': 109, 'tir': 110, 'depuis': 111, 'ministre': 112, 'sans': 113, 'toujours': 114, 'parler': 115, 'parole': 116, 'dire': 117, 'dune': 118, 'christiane': 119, 'temps': 120, 'politique': 121, 'c': 122, 'comment': 123, 'victimes': 124, 'taubira': 125, 'nos': 126, 'toutes': 127, 'votre': 128, 'nest': 129, 'voir': 130, 'violences': 131, 'quoi': 132, 'ils': 133, 'quon': 134, '2018': 135, 'juste': 136, 'oui': 137, 'peu': 138, 'dun': 139, 'féminisme': 140, 'parle': 141, '2': 142, 'deux': 143, 'bon': 144, 'trop': 145, 'beaucoup': 146, 'vie': 147, 'sexuelles': 148, 'sexuel': 149, 'soir': 150, 'quil': 151, 'collectif': 152, '1': 153, 'aurait': 154, 'elles': 155, 'gens': 156, 'avant': 157, 'd': 158, 'moins': 159, 'face': 160, 'bravo': 161, 'bonne': 162, 'avait': 163, 'genre': 164, 'jamais': 165, 'na': 166, 'jour': 167, '2017': 168, 'porc': 169, 'coup': 170, 'aujourdhui': 171, 'droit': 172, 'soit': 173, 'ni': 174, 'doit': 175, 'pr': 176, 'vrai': 177, 'sous': 178, 'amp': 179, 'dis': 180, 'toute': 181, 'vraiment': 182, 'justice': 183, 'autres': 184, 'auroreberge': 185, '25': 186, 'pense': 187, 'première': 188, 'mois': 189, 'société': 190, 'paris': 191, 'te': 192, 'l': 193, 'diffamation': 194, 'sera': 195, 'propos': 196, 'franceinfo': 197, 'selon': 198, 'nouvelle': 199, 'd’une': 200, 'veut': 201, 'janvier': 202, 'mieux': 203, 'emmanuelmacron': 204, 'sport': 205, 'nationale': 206, 'dont': 207, 'demain': 208, 'nouveau': 209, 'fois': 210, 'premier': 211, 'qu’on': 212, 'font': 213, 'puissante': 214, 'gros': 215, 'trump': 216, 'sexistes': 217, 'leurs': 218, 'campagne': 219, 'pute': 220, 'allez': 221, 'chez': 222, 'place': 223, 'j’ai': 224, 'personne': 225, 'mal': 226, 'emmanuel': 227, 'vidéo': 228, 'racisme': 229, 'vient': 230, 'hashtag': 231, 'lieu': 232, 'theresamay': 233, 'débat': 234, 'soutien': 235, 'cela': 236, 'courage': 237, 'journaliste': 238, 'grand': 239, 'retour': 240, 'certains': 241, 'plainte': 242, 'dêtre': 243, 'reste': 244, 'accusé': 245, 'déjà': 246, 'weinstein': 247, 'conne': 248, 'français': 249, 'quune': 250, 'vos': 251, 'ceux': 252, 'vu': 253, 'différence': 254, 'millions': 255, 'victime': 256, 'tellement': 257, 'question': 258, 'toi': 259, 'presse': 260, 'slt': 261, 'lannée': 262, 'sexuelle': 263, 'petite': 264, 'gouvernement': 265, 'culture': 266, 'balance': 267, 'surtout': 268, 'ny': 269, 'légalité': 270, 'quun': 271, 'marche': 272, 'autre': 273, 'nom': 274, 'violence': 275, 'chancelière': 276, 'jeune': 277, 'vue': 278, 'aujourd’hui': 279, 'maintenant': 280, 'celui': 281, 'pouvoir': 282, 'quotidien': 283, 'tribune': 284, 'cet': 285, 'plein': 2 ...

# %%
train_sequences = tokenizer.texts_to_sequences(X_train)
train_padded = pad_sequences(train_sequences, padding=padding_type, maxlen=max_length)

validation_sequences = tokenizer.texts_to_sequences(X_test)
validation_padded = pad_sequences(validation_sequences, padding=padding_type, maxlen=max_length)

# %%
#tokenizing labels
label_tokenizer = Tokenizer()
label_tokenizer.fit_on_texts(y)

training_label_seq = np.array(label_tokenizer.texts_to_sequences(y_train))
validation_label_seq = np.array(label_tokenizer.texts_to_sequences(y_test))

# %%
#creating model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 120, 16)           16000
#
#  global_average_pooling1d_7   (None, 16)               0
#  (GlobalAveragePooling1D)
#
#  dense_14 (Dense)            (None, 24)                408
#
#  dense_15 (Dense)            (None, 6)                 150
#
# =================================================================
# Total params: 16,558
# Trainable params: 16,558
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 30
history = model.fit(train_padded, training_label_seq, epochs=num_epochs, 
                    validation_data=(validation_padded, validation_label_seq), 
                    verbose=2)
# Out:
# Epoch 1/30
# 69/69 - 2s - loss: 1.6562 - accuracy: 0.3132 - val_loss: 1.4296 - val_accuracy: 0.3164 - 2s/epoch - 22ms/step
# Epoch 2/30
# 69/69 - 0s - loss: 1.0907 - accuracy: 0.4893 - val_loss: 0.7843 - val_accuracy: 0.6836 - 271ms/epoch - 4ms/step
# Epoch 3/30
# 69/69 - 0s - loss: 0.6937 - accuracy: 0.6868 - val_loss: 0.6527 - val_accuracy: 0.6836 - 326ms/epoch - 5ms/step
# Epoch 4/30
# 69/69 - 0s - loss: 0.6399 - accuracy: 0.6868 - val_loss: 0.6352 - val_accuracy: 0.6836 - 269ms/epoch - 4ms/step
# Epoch 5/30
# 69/69 - 0s - loss: 0.6290 - accuracy: 0.6868 - val_loss: 0.6298 - val_accuracy: 0.6836 - 360ms/epoch - 5ms/step
# Epoch 6/30
# 69/69 - 0s - loss: 0.6257 - accuracy: 0.6868 - val_loss: 0.6267 - val_accuracy: 0.6836 - 308ms/epoch - 4ms/step
# Epoch 7/30
# 69/69 - 0s - loss: 0.6220 - accuracy: 0.6868 - val_loss: 0.6235 - val_accuracy: 0.6836 - 350ms/epoch - 5ms/step
# Epoch 8/30
# 69/69 - 0s - loss: 0.6198 - accuracy: 0.6868 - val_loss: 0.6215 - val_accuracy: 0.6836 - 284ms/epoch - 4ms/step
# Epoch 9/30
# 69/69 - 0s - loss: 0.6179 - accuracy: 0.6868 - val_loss: 0.6199 - val_accuracy: 0.6836 - 360ms/epoch - 5ms/step
# Epoch 10/30
# 69/69 - 0s - loss: 0.6158 - accuracy: 0.6868 - val_loss: 0.6179 - val_accuracy: 0.6836 - 369ms/epoch - 5ms/step
# Epoch 11/30
# 69/69 - 0s - loss: 0.6118 - accuracy: 0.6868 - val_loss: 0.6152 - val_accuracy: 0.6836 - 482ms/epoch - 7ms/step
# Epoch 12/30
# 69/69 - 1s - loss: 0.6087 - accuracy: 0.6868 - val_loss: 0.6126 - val_accuracy: 0.6836 - 501ms/epoch - 7ms/step
# Epoch 13/30
# 69/69 - 0s - loss: 0.6034 - accuracy: 0.6868 - val_loss: 0.6072 - val_accuracy: 0.6836 - 389ms/epoch - 6ms/step
# Epoch 14/30
# 69/69 - 0s - loss: 0.5979 - accuracy: 0.6868 - val_loss: 0.6017 - val_accuracy: 0.6836 - 404ms/epoch - 6ms/step
# Epoch 15/30
# 69/69 - 0s - loss: 0.5885 - accuracy: 0.6868 - val_loss: 0.5933 - val_accuracy: 0.6836 - 391ms/epoch - 6ms/step
# Epoch 16/30
# 69/69 - 1s - loss: 0.5759 - accuracy: 0.6868 - val_loss: 0.5844 - val_accuracy: 0.6836 - 518ms/epoch - 8ms/step
# Epoch 17/30
# 69/69 - 0s - loss: 0.5621 - accuracy: 0.6913 - val_loss: 0.5739 - val_accuracy: 0.6815 - 373ms/epoch - 5ms/step
# Epoch 18/30
# 69/69 - 0s - loss: 0.5461 - accuracy: 0.7000 - val_loss: 0.5617 - val_accuracy: 0.6931 - 409ms/epoch - 6ms/step
# Epoch 19/30
# 69/69 - 0s - loss: 0.5303 - accuracy: 0.7149 - val_loss: 0.5505 - val_accuracy: 0.6963 - 370ms/epoch - 5ms/step
# Epoch 20/30
# 69/69 - 0s - loss: 0.5117 - accuracy: 0.7331 - val_loss: 0.5427 - val_accuracy: 0.6931 - 351ms/epoch - 5ms/step
# Epoch 21/30
# 69/69 - 0s - loss: 0.4952 - accuracy: 0.7522 - val_loss: 0.5283 - val_accuracy: 0.7143 - 321ms/epoch - 5ms/step
# Epoch 22/30
# 69/69 - 0s - loss: 0.4783 - accuracy: 0.7626 - val_loss: 0.5199 - val_accuracy: 0.7206 - 340ms/epoch - 5ms/step
# Epoch 23/30
# 69/69 - 0s - loss: 0.4582 - accuracy: 0.7794 - val_loss: 0.5121 - val_accuracy: 0.7280 - 276ms/epoch - 4ms/step
# Epoch 24/30
# 69/69 - 0s - loss: 0.4442 - accuracy: 0.7876 - val_loss: 0.5274 - val_accuracy: 0.7111 - 389ms/epoch - 6ms/step
# Epoch 25/30
# 69/69 - 0s - loss: 0.4321 - accuracy: 0.7985 - val_loss: 0.4999 - val_accuracy: 0.7407 - 299ms/epoch - 4ms/step
# Epoch 26/30
# 69/69 - 0s - loss: 0.4177 - accuracy: 0.8030 - val_loss: 0.4967 - val_accuracy: 0.7407 - 313ms/epoch - 5ms/step
# Epoch 27/30
# 69/69 - 0s - loss: 0.4086 - accuracy: 0.8071 - val_loss: 0.4991 - val_accuracy: 0.7354 - 303ms/epoch - 4ms/step
# Epoch 28/30
# 69/69 - 0s - loss: 0.3974 - accuracy: 0.8153 - val_loss: 0.4924 - val_accuracy: 0.7471 - 328ms/epoch - 5ms/step
# Epoch 29/30
# 69/69 - 0s - loss: 0.3897 - accuracy: 0.8157 - val_loss: 0.4915 - val_accuracy: 0.7481 - 285ms/epoch - 4ms/step
# Epoch 30/30
# 69/69 - 0s - loss: 0.3791 - accuracy: 0.8221 - val_loss: 0.4912 - val_accuracy: 0.7503 - 324ms/epoch - 5ms/step

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

# %%
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
#visualizing embedded words
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
def decode_sentence(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

# %%
e = model.layers[0]
weights = e.get_weights()[0]
print(weights.shape)
# Out:
# (1000, 16)

# %%
import io
out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('meta.tsv', 'w', encoding='utf-8')
for word_num in range(1, vocab_size):
    word = reverse_word_index[word_num]
    embeddings = weights[word_num]
    out_m.write(word + "\n")
    out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")
out_v.close()
out_m.close()

#use tensorflow embedding projector to visualize results by uploading this vector and metadata

# %%
y_pred = model.predict(validation_padded)
#print(validation_padded.shape)
print(validation_label_seq.shape)
print(y_pred.shape)

#print(y_pred)
print(y_pred)
#confusion_matrix = tf.math.confusion_matrix(labels=validation_label_seq, predictions=y_pred)
# Out:
# (945, 1)
# (945, 6)
# [[1.98611979e-05 7.52756000e-01 2.47027114e-01 7.55505389e-05
#   6.44062820e-05 5.70579687e-05]
#  [1.03955945e-05 8.91364038e-01 1.08516552e-01 4.26884872e-05
#   3.51699236e-05 3.10845971e-05]
#  [1.54580503e-05 7.44475067e-01 2.55351275e-01 6.07344664e-05
#   5.19361674e-05 4.55623012e-05]
#  ...
#  [8.17735054e-05 1.86627433e-01 8.12639117e-01 2.33964485e-04
#   2.20763613e-04 1.96997004e-04]
#  [3.48673784e-05 7.59568810e-01 2.40071580e-01 1.23904276e-04
#   1.05827938e-04 9.50479298e-05]
#  [1.43888810e-05 7.61226356e-01 2.38611102e-01 5.70549855e-05
#   4.84501179e-05 4.27002706e-05]]

# %% [markdown]
# ### Adding weight to the sexist words

# %%
import re

stereotype_liste = []

with open('stereotype_liste.txt',encoding='utf8') as f:
    stereotype_liste = f.readlines()
  


weighted_words = [re.sub(r"\n",'',i) for i in stereotype_liste]


print(weighted_words)
# Out:
# ['femme', 'fille', 'nana', 'meuf', 'chienne', 'poule', 'garce', 'femelle', 'princesse', 'chose', 'fillette', 'femme objet', 'femme-objet', 'objet', 'ruminante', 'bonne femme', 'potiche', 'biche', 'cocotte', 'journaleuse', 'sex symbol', 'sex symbole', 'daronne', 'diablesse', 'macrelle', 'gonzesse', 'miss', 'femme parfaite', 'dinde', 'feumeu', 'sainte', 'beurette', 'hardeuse', 'dame', 'madame', 'petite dame', 'vraie femme', 'pauvre femme', 'lesbienne ', 'conne', 'connasse', 'cageot', 'casse-bonbon', 'casse-couille', 'casse-couilles', 'chiennasse', 'chienne', 'emmerdeuse', 'folle', 'garage à bite', 'garce', 'gouine', 'gourdasse', 'gourde', 'morue', 'pétasse', 'pouf', 'pouffiasse', 'poufiasse', 'pute', 'salope', 'sorcière', 'traînée', 'vipère', 'bonne', 'petite', 'moche', 'vieille', 'bombe', 'poitrine', 'sein', 'fesses', 'cul', 'grosse', 'vache', 'truie', 'boudin', 'jupe', 'minijupe ', 'mini-jupe', 'robe', 'décolleté', 'cuisses', 'sexy', 'chatte', 'maquillage', 'baleine', 'belle', 'coquette', 'jolie', 'élégante', 'bouche', 'jambe', 'talons', 'fragile', 'faible', 'curieuse', 'bavarde', 'jalouse', 'frivole', 'hystérique', 'hystéro', 'dépensière', 'peureuse', 'cancanière', 'facile', 'ragot', 'pleurnicharde', 'superficielle', 'volage', 'fatale', 'cucul', 'provocatrice', 'argent', 'blonde', 'idiote', 'incompétente', 'douce', 'tendre', 'attentionnée', 'rancunière', 'dévouée', 'naïve', 'pudique', 'discrète', 'aimante', 'sensible', 'nymphomane', 'nympho', 'allumeuse', 'forte', 'maternelle', 'instinct maternel', 'propre', 'patiente', 'soigneuse', 'protectrice', 'brillante', 'danse', 'secrétaire', 'infirmière', 'aide-soignante', 'femme de ménage', 'mère', 'mère au foyer', 'épouse', 'poupée', 'dinette', 'enfant', 'rose', 'cuisine', 'ménage', 'aspirateur', 'casserole', 'vaisselle', 'serpillière', 'manger', 'coureuse', 'bonniche', 'porter la culotte']

# %%
# ==> ajouter les poids
# ==> matrice de confusion
# ==> revoir clean
# ==> meler plusieurs methodes
# ==> tester avec des paramètres différents
